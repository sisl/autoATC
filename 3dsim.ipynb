# %%
include("pattern.jl");
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
include("3dsim.jl");

# %%
# α = 1.0;

# policy_prefix = "greedyRandom_"
# #policy_prefix = ""
# Aopt = loadPolicy(1.,0.0f0, prefix=policy_prefix)
# ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# ctmdpPolicy([:LD2, :RB1, :R, :U1])
# Out:
# (1,:ϕ1_LD3)

# %%
include("CTMDP_mcts.jl")
# Out:
# (anonymous function)

# %%
@time mctsPolicy([:LD2, :RB1, :R, :U1])
# Out:
# elapsed time: 0.
# 619088836 seconds (44693492 bytes allocated)
# (0,:∅)

# %%
findFirsti2()
# Out:
# @methodswith not defined
# while loading In[519], in expression starting on line 1

# %%
function findFirsti(Snow::SType, trantimes::typeof(pattern.teaTime), rngState)
    #Find which state will transition
    N = length(Snow)

    tmin = Inf
    ifirst = 1
    for i in 1:N
       t = -trantimes[Snow[i]] * log(1-rand(rngState))
       if t < tmin
         ifirst = i
         tmin = t
       end
    end
    
    return ifirst
end



function getNextState!(Snew::SType, Snow::SType, a::typeof(pattern.g_noaction), trantimes::typeof(pattern.teaTime), rngState)
    #Snew = copy(Snow)
    ifirst = findFirsti(Snow, trantimes, rngState)
    #Only transition the one with the earliest event in the race!
    for i in 1:length(Snew)
        if i == ifirst
            Snew[ifirst] = pattern.randomChoice(Snow[ifirst], a[1] == ifirst, a[2]; rngState=rngState)
        else
            Snew[i] = Snow[i] 
        end
    end
    
    return nothing
end
# Out:
# getNextState! (generic function with 1 method)

# %%
@time for lo in 1:1e5 findFirsti(Snow, pattern.teaTime, rng) end
# Out:
# elapsed time: 0.
# 034552143 seconds (96 bytes allocated)

# %%
@time for lo in 1:1e5 getNextState(Snow, pattern.g_noaction, rng)  end
# Out:
# elapsed time: 1
# .515722517 seconds (173031792 bytes allocated, 76.64% gc time)

# %%
@time for lo in 1:1e5 getNextState2(Snow, pattern.g_noaction, pattern.teaTime, rng)  end
# Out:
# elapsed time: 1
# .151394736 seconds (112743368 bytes allocated, 77.99% gc time)

# %%
@time for lo in 1:1e5 getNextState!(Snew, Snow, pattern.g_noaction, pattern.teaTime, rng)  end
# Out:
# elapsed time: 0.
# 054474023 seconds (96 bytes allocated)

# %%
Snew = [:U, :R, :U1, :U2];

# %%
rng = MersenneTwister()
# Out:
# MersenneTwister(DSFMT_state(Int32[748398797,1073523691,-1738140313,1073664641,-1492392947,1073490074,-1625281839,1073254801,1875112882,1073717145  …  943540191,1073626624,1091647724,1073372234,-1273625233,-823628301,835224507,991807863,382,0]),Uint32[0x00000000])

# %%
ProfileView.view()
# Out:
# ProfileData(95x24 Array{RGB{Float64},2}:
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.5503120972657082,0.0,0.27233428459349773)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)                               ,[0x00007f7320380b25=>LineInfo("???","???",140132438510373,true,140132438510373),0x00007f730c3e4987=>LineInfo("jlcall_findFirsti2_21254","",-1,true,140132103375239),0x00007f731fffb9a8=>LineInfo("???","???",140132434819496,true,140132434819496),0x00007f731fedda58=>LineInfo("???","???",140132433648216,true,140132433648216),0x00007f731ff4fb93=>LineInfo("???","???",140132434115475,true,140132434115475),0x00007f730c3e484f=>LineInfo("anonymous","profile.jl",1,false,140132103374927),0x00007f732030057d=>LineInfo("???","???",140132437984637,true,140132437984637),0x00007f731de9a403=>LineInfo("resolve_globals","./inference.jl",1804,false,140132399817731),0x00007f731de9a2ee=>LineInfo("resolve_globals","./inference.jl",1839,false,140132399817454),0x00007f731048e328=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140132171178792),0x00007f73204af922=>LineInfo("???","???",140132439750946,true,140132439750946),0x00007f731ff9ee67=>LineInfo("???","???",140132434439783,true,140132434439783),0x00007f731f91712d=>LineInfo("__poll","/lib/x86_64-linux-gnu/libc.so.6",-1,true,140132427591981),0x00000000004014bd=>LineInfo("???","???",4199613,true,4199613),0x0101010001000000=>LineInfo("???","???",72340168543043584,true,72340168543043584),0x00007f7310b78ff1=>LineInfo("dsfmt_genrand_close_open","/usr/bin/../lib/x86_64-linux-gnu/julia/libdSFMT.so",-1,true,140132178431985),0x00007f731dec3ad2=>LineInfo("typeinf","./inference.jl",1409,false,140132399987410),0x00007f731048e197=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140132171178391),0x00007f731d9a21f5=>LineInfo("ht_keyindex","dict.jl",473,false,140132394607093),0x00007f731fee10be=>LineInfo("jl_apply_generic","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140132433662142),0x00007f731048e1a7=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140132171178407),0x00007f7320440b38=>LineInfo("???","???",140132439296824,true,140132439296824),0x00007f730c3e4a94=>LineInfo("findFirsti2","In[2]",9,false,140132103375508),0x00007f73200e19a7=>LineInfo("???","???",140132435761575,true,140132435761575),0x00007f731fee1051=>LineInfo("jl_apply_generic","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140132433662033),0x00007f731d97b1ef=>LineInfo("anonymous","task.jl",340,false,140132394447343),0x00007f730c3e4ad1=>LineInfo("findFirsti2","In[2]",10,false,140132103375569),0x00007f731de6f018=>LineInfo("jlcall__2A__4167","/usr/bin/../lib/x86_64-linux-gnu/julia/sys.so",-1,true,140132399640600),0x00007f731ff0f42e=>LineInfo("???","???",140132433851438,true,140132433851438),0x00007f732037c66d=>LineInfo("???","???",140132438492781,true,140132438492781),0x00007f7320205f02=>LineInfo("???","???",140132436958978,true,140132436958978),0x00007f731ff34e7d=>LineInfo("???","???",140132434005629,true,140132434005629),0x00007f731ff3b633=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140132434032179),0x00007f730c3e4cf1=>LineInfo("jlcall_<_21255","",-1,true,140132103376113),0x00007f731deaed1c=>LineInfo("inlining_pass","./inference.jl",2652,false,140132399901980),0x00007f7320739aa7=>LineInfo("???","???",140132442413735,true,140132442413735),0x00007f73205d8d11=>LineInfo("???","???",140132440968465,true,140132440968465),0x00007f7320460106=>LineInfo("???","???",140132439425286,true,140132439425286),0x00007f731feddac5=>LineInfo("???","???",140132433648325,true,140132433648325),0x00007f730c3e4b0c=>LineInfo("findFirsti2","In[2]",10,false,140132103375628),0x00007f7310b78f75=>LineInfo("dsfmt_genrand_close1_open2","/usr/bin/../lib/x86_64-linux-gnu/julia/libdSFMT.so",-1,true,140132178431861),0x00007f731fedd8c7=>LineInfo("???","???",140132433647815,true,140132433647815),0x00007f731ff3b5b8=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,1401324 ...
#  TagData(0x00007f731d97005e,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97005e,0)      TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  ⋮                               ⋱
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)   …  TagData(0x00007f731deb831a,0)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f731d97b1ef,0)      TagData(0x0000000000000000,-1),12)

# %%
# if isdefined(current_module(),:LastMain) && isdefined(LastMain,:PyPlot)
#   using LastMain.PyPlot
#   using LastMain.PyCall
# else
#   using PyPlot
#   using PyCall
# end
# @pyimport matplotlib.animation as anim
# linewidth = 0.4
# plt.rc("axes", linewidth=linewidth)
# plt.rc("font", family="")
# plt.rc("axes", titlesize="medium", labelsize="medium")
# plt.rc("xtick", labelsize="small")
# plt.rc("xtick.major", width=linewidth/2)
# plt.rc("ytick", labelsize="small")
# plt.rc("ytick.major", width=linewidth/2)
# plt.rc("legend", fontsize="large")
# plt.rc("axes" ,unicode_minus=false)

# %%
#airplaneType.simPars.maxNoiseAlt = 0.

# %%
# srand(pattern.rng,uint32(1));
aircraftList = [airplane(50,:U1), airplane(50, :LD2), airplane(50, :R), airplane(50, :T)];

# %%
# @time (idmin, tmax, alertCount) = simulate!(aircraftList,100,:Smart,ctmdpPolicy, stopEarly=true, savepath=true); tmax, alertCount
# Out:
# 0.0
# Ready for command:
# [(:ϕ1_U1,false),(:ϕ1_LD2,false),(:R,true),(:ϕ1_T,false)](0,:∅)
# 44.25Ready for command:[(:U1,false),(:LD2,false),(:ϕ3_U1,false),(:T,true)](2,:ϕ1_LD3)
# 53.25Ready for command:[(:U1,true),(:LD2,true),(:U1,false),(:R,false)](0,:∅)
# 65.25Ready for command:[(:ϕ2_LX1,false),(:ϕ2_LD3,false),(:U1,true),(:R,false)](3,:ϕ1_RX1)
# 83.25Ready for command:[(:LX1,true),(:ϕ3_LD3,false),(:ϕ2_RX1,false),(:R,false)](0,:∅)
# 96.5Ready for command:[(:ϕ1_LD1,false),(:LD3,true),(:RX1,false),(:R,false)](0,:∅)
# 99.5Ready for command:[(:ϕ1_LD1,false),(:ϕ1_LB2,false),(:RX1,true),(:R,false)](0,:∅)
# elapsed time: 0.459863585 seconds (13530668 bytes allocated)
# (100,2)

# %%
using ProfileView

# %%
Profile.clear()
Profile.init(n=1000000*10)

# %%
@profile (idmin, tmax, alertCount) = simulate!(aircraftList,100,:Smart,mctsPolicy, stopEarly=true, savepath=true); #tmax, alertCount
# Out:
# ([2,3],100,2,100.25,None[])

# %%
ProfileView.view()
# Out:
# ProfileData(3830x64 Array{RGB{Float64},2}:
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0),[0x00007ff1fcaab598=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302891928),0x00007ff1fa998683=>LineInfo("hash_64_64","./hashing.jl",21,false,140677268211331),0x00007ff1fca43241=>LineInfo("???","???",140677302465089,true,140677302465089),0x00007ff1ec1f91e7=>LineInfo("ht_keyindex","dict.jl",471,false,140677025337831),0x00007ff1fcaaaac4=>LineInfo("jl_gc_collect","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302889156),0x00007ff1ec1fa3c0=>LineInfo("getNextState","/home/zouhair/Dropbox/Research/autoATC/CTMDP_mcts.jl",39,false,140677025342400),0x00007ff1faa5532e=>LineInfo("IOBuffer","./iobuffer.jl",46,false,140677268984622),0x00007ff1ec1fbab9=>LineInfo("getReward","/home/zouhair/Dropbox/Research/autoATC/CTMDP_mcts.jl",57,false,140677025348281),0x00007ff1ec1faae1=>LineInfo("jlcall_<_21125","",-1,true,140677025344225),0x00007ff1fcaa9cdc=>LineInfo("???","???",140677302885596,true,140677302885596),0x00007fffa9d6aca0=>LineInfo("???","???",140736042806432,true,140736042806432),0x00007ff1ec1fbf8a=>LineInfo("_mapreduce","reduce.jl",169,false,140677025349514),0x00007ff1fcaa9d75=>LineInfo("???","???",140677302885749,true,140677302885749),0x00007ff1fa511949=>LineInfo("getindex","dict.jl",616,false,140677263464777),0x00007ff1faa4fa7e=>LineInfo("ht_keyindex","./dict.jl",478,false,140677268961918),0x00007ff1fc419143=>LineInfo("???","???",140677296001347,true,140677296001347),0x00007ff1ecffe1a7=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140677040038311),0x00007ff1fa52ed42=>LineInfo("ht_keyindex2","dict.jl",516,false,140677263584578),0x00007ff1fcaa9d8b=>LineInfo("???","???",140677302885771,true,140677302885771),0x00007ff1ec1fbc20=>LineInfo("NcolNtaxi","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",294,false,140677025348640),0x00007ff1fca4d9f3=>LineInfo("???","???",140677302508019,true,140677302508019),0x00007ff1fca42949=>LineInfo("???","???",140677302462793,true,140677302462793),0x00007ff1faa4fadc=>LineInfo("ht_keyindex","./dict.jl",482,false,140677268962012),0x00007ff1fca4da58=>LineInfo("???","???",140677302508120,true,140677302508120),0x00007ff1fcaaab38=>LineInfo("jl_gc_collect","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302889272),0x00007ff1fa52ca75=>LineInfo("simulate","/home/zouhair/Dropbox/Research/autoATC/MCTS.jl",96,false,140677263575669),0x00007ff1fca59666=>LineInfo("jl_object_id","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302556262),0x00007ff1ecffe334=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140677040038708),0x00007ff1fcaa9b9a=>LineInfo("???","???",140677302885274,true,140677302885274),0x00007ff1fcaab4b3=>LineInfo("allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302891699),0x00007ff1ec1f9470=>LineInfo("validActions","/home/zouhair/Dropbox/Research/autoATC/pattern.jl",333,false,140677025338480),0x00007ff1ecffe1cb=>LineInfo("log","/usr/bin/../lib/x86_64-linux-gnu/julia/libopenlibm.so",-1,true,140677040038347),0x00007ff1fca510ae=>LineInfo("jl_apply_generic","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302522030),0x00007ff1fca4da41=>LineInfo("???","???",140677302508097,true,140677302508097),0x00007ff1faa458fb=>LineInfo("print_to_string","./string.jl",23,false,140677268920571),0x00007ff1fcaa9b01=>LineInfo("???","???",140677302885121,true,140677302885121),0x00007ff1fc41c7b0=>LineInfo("__libc_malloc","/lib/x86_64-linux-gnu/libc.so.6",-1,true,140677296015280),0x00007ff1ec2077da=>LineInfo("jlcall_simulate!_21267","",-1,true,140677025396698),0x00007ff1fca9a237=>LineInfo("julia_trampoline","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302821431),0x00007ff1fcaab5c2=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140677302891970),0x00007ff1fa52c477=>LineInfo ...
#  TagData(0x00007ff1fa4e005e,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4e005e,0)      TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  ⋮                               ⋱
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007ff1fa4eb1ef,0)      TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1),12)

# %%
# plot([ sqrt(posType.distance2(aircraftList[2].path[i], aircraftList[3].path[i]))-150 < 0 for i in 1:length(aircraftList[2].path)])

# plot([ abs(aircraftList[2].path[i].d - aircraftList[3].path[i].d)-30 < 0 for i in 1:length(aircraftList[2].path)])
# ylim([-20, 20])
# xlim([10000, 15000])
# grid("on");

# %%
# make3d = false
# function plot3dsim(i)
#     outOfData = false;
# b=0
# g=0
# if(make3d)
#     ax = PyPlot.gca(projection="3d")
#     #ax[:view_init](0, 180)
#     ax[:pbaspect] = [1,1,0.6]   
# else
#     #PyPlot.clf()
#     ax = plt.gca()
#         clf()
#         hold("on")
# end

# D3 = Vector{Float64}[]
# XY = Vector{Float64}[]
    
#     dL = 20;
#     dS = 20
# for ac in aircraftList
#         range = (1:dL) + (i-1)*dS
#         if(range[end] > length(ac.path))
#             range = (length(ac.path)-dL):length(ac.path)
#             outOfData = true 
#         end

#     Y = [p.n for p in ac.path[range]];
#     X = [p.e for p in ac.path[range]];
#     Z = -[p.d for p in ac.path[range]];
#     N = length(X)
#     if(make3d)
#         di = 100
#         for i in 1:di:(N-di)
#             idx = i:(i+di)
#             r = clip( mean(Z[idx]) / 300 , .05, 1.)    
#             PyPlot.plot3D(Y[idx],X[idx],Z[idx],color=(r,g,0))
#         end
#         push!(D3, [Y[end], X[end], Z[end]])
#         PyPlot.xlabel("North")
#         PyPlot.ylabel("East")
#         PyPlot.zlabel("Altitude")
#     else
#         PyPlot.plot(X,Y)
#         #PyPlot.axis("equal")
#         #PyPlot.ylabel("North")
#         #PyPlot.xlabel("East")
#     end
#     g += 0.25
# end

# for d in D3
#     PyPlot.scatter3D(d[1],d[2],d[3],marker="o")         
# end
# #PyPlot.grid("on")
# if make3d
#     ax[:set_ylim3d]([-5000, 5000])  
# else
#     ylim([-4000, 4000])
#     xlim([-10000, 10000])
#     grid("on")
#         hold("off")
# end
    
# return outOfData
    
# end
# #plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/3dpattern.pdf", bbox_inches="tight")

# %%
# # plot in an external window since it doesn't work yet in IJulia
# pygui(true)
# # tell PyPlot that the plot is interactive
# PyPlot.ion()
# # . . . and that previous plots are overwritten
# PyPlot.hold(false)
# # start time-stepping loop
# n = 1;
# while(true)
#     outOfData = plot3dsim(n)
#     # . . .
#     # Then force the draw
#     PyPlot.draw()
#     n +=1 ;
#     if(outOfData)
#         break
#     end
# end

# %%
# pygui(false)
# hold("on")
# for i in 1:4
#     xHist = [pattern.g_sn[(s)] for s in aircraftList[i].sLocHist];
#     plot(xHist)
# end
# yticks(1:length(pattern.g_allstates[1:27]), pattern.g_allstates_string[1:27]);
# grid("on")

# %%
function randomStart()
    rstart_in = ()-> [airplane(46 + (rand()-0.5)*3,s) for s in pattern.allstates[rand(3:length(pattern.allstates), 4)]];
    acList = rstart_in()

    idmin = [0,0]
    notok = (ACLIST)-> getDmin!(idmin, ACLIST)[1] <=  0
        
    while(notok(acList))
        acList = rstart_in()
    end
    return acList
end
# Out:
# randomStart (generic function with 1 method)

# %%
tic()
tBatchTime = 3600*10 #Total run time per batch
N = 2 #Total Number of batches (total simulated time is tBatch * N )

betaVals = [0.0f0, 0.001f0, 0.005f0, 0.01f0, 0.05f0]
betaVals = [0.0f0] #, 0.001f0, 0.005f0, 0.01f0, 0.05f0]

betaValStr = [string(β) for β in betaVals]
NbetaVals = length(betaVals)
atcTypes = [:Smart, :None] 
NatcTypes = length(atcTypes)

tStat = zeros(Float32, NbetaVals,NatcTypes,N)
tTotals = zeros(tStat)
flightTimes = zeros(tStat)

alertCounts = zeros(Uint32, NbetaVals,NatcTypes,N)
nNMACcounts = zeros(alertCounts)
toc()
#Last 3 is for 3D position @ collision
#collisionPos = (Symbol => Array{Float64,3})[a => fill(NaN, NbetaVals,N,3) for a in atcTypes];
# Out:
# elapsed time: 0.
# 10622351 seconds

# %%
#Reinit sim seed for repeatibility
srand(pattern.rng,uint32(1))
startTime = time();
@time for (betaIdx, beta) in enumerate(betaVals)
    #Use the appropriate policy
    s0 = time()
#     Aopt = loadPolicy(1., beta, prefix=policy_prefix)
    @printf("Loading policy took %.0f(s)\n",time()-s0)
    for (atcIdx, atcType) in enumerate(atcTypes)  
        #We only need to run the first beta for the None case
        #Copy it over for simplicity
        if (atcType == :None && betaIdx > 1)
            tStat[betaIdx, atcIdx, :] = tStat[1, atcIdx, :]
            flightTimes[betaIdx, atcIdx, :] = flightTimes[1, atcIdx, :]
            alertCounts[betaIdx, atcIdx, :] = alertCounts[1, atcIdx, :]
            nNMACcounts[betaIdx, atcIdx, :] = nNMACcounts[1, atcIdx, :] 
            tTotals[betaIdx, atcIdx, :] = tTotals[1, atcIdx, :] 

            #collisionPos[atcType][betaIdx,:,:] = collisionPos[atcType][1,:,:]
            continue
        end
        #Simulate N trajectories
        nextPrintTime = time() + 60 
        for i in 1:N
            
            while tTotals[betaIdx, atcIdx, i] < tBatchTime
                now = time()
                if now >= nextPrintTime
                    nextPrintTime = now + 60
                    println(now-startTime, "(s) at betaIdx=",betaIdx, " atcIdx=",atcIdx, " i = ", i)
                end    
                
                #First, initialize the position
                aircraftList = randomStart()
                #Simulate the policy
                simTime = tBatchTime-tTotals[betaIdx, atcIdx, i]
                (idmin, tmax, alertCount, flightTime) = simulate!(aircraftList,simTime,
                                                                  atcType,mctsPolicy, #ctmdpPolicy,
                                                                  stopEarly=true, savepath=false);
                
                if (tmax < simTime ) #we finished early, must have been an NMAC
                    nNMACcounts[betaIdx, atcIdx, i] += 1
                end
#                 @printf("simTime = %.2f, flightTime = %.2f , tmax = %.2f, nMac = %d\n", 
#                         simTime/3600, flightTime/3600, tmax/3600, nNMACcounts[betaIdx, atcIdx, i] )
                
                tTotals[betaIdx, atcIdx, i] += tmax
                alertCounts[betaIdx, atcIdx, i] += alertCount
                flightTimes[betaIdx, atcIdx, i] += flightTime
                tStat[betaIdx, atcIdx, i] = tmax
                
                #Whine if for some reason we got a collision right
                #after we started... randomStart() should not cause this
                if(tmax == 0)
                    error("Collision right after start. This shouldn't happen!")
                end
            end

            #Keep track of statistics
#             if !(0 in idmin)
#                 collisionPos[atcType][betaIdx,i,:] = 
#                     [aircraftList[idmin[1]].posNED.n, aircraftList[idmin[1]].posNED.e, aircraftList[idmin[1]].posNED.d]
#             end
        end
  end
end
# Out:
# Loading policy took 0
# (s)
# 214
# .01535987854004(s) at betaIdx=1 atcIdx=1 i = 1
# interrupt
# while loading In[12], in expression starting on line 4
#
#  in convert at base.jl:21
#  in push! at array.jl:462
#  in validActions at /home/zouhair/Dropbox/Research/autoATC/pattern.jl:342
#  in simulate at /home/zouhair/Dropbox/Research/autoATC/MCTS.jl:87
#  in simulate at /home/zouhair/Dropbox/Research/autoATC/MCTS.jl:120 (repeats 6 times)
#  in selectAction! at /home/zouhair/Dropbox/Research/autoATC/MCTS.jl:69
#  in anonymous at /home/zouhair/Dropbox/Research/autoATC/CTMDP_mcts.jl:88
#  in runAutoATC at /home/zouhair/Dropbox/Research/autoATC/3dsim.jl:14
#  in simulate! at /home/zouhair/Dropbox/Research/autoATC/3dsim.jl:66
#  in anonymous at util.jl:37

# %%
flightTimes
# Out:
# 1x2x2 Array{Float32,3}:
# [:, :, 1] =
#  6237.94  0.0
#
# [:, :, 2] =
#  0.0  0.0

# %%
sum(flightTimes[:,1,:])/3600 ./sum(nNMACcounts[:,1,:])*1.0
# Out:
# 1.7327604293823242

# %%
mcts.stats
# Out:
# Dict{Array{Symbol,1},StateStat} with 2203332 entries:
#   [:RB2,:ϕ2_LD2,:ϕ3_RD2,:… => StateStat(Int32[1,1,1],Float32[0.0,-1000.0,-1000.…
#   [:ϕ1_RD1,:ϕ2_GO,:ϕ2_RB2… => StateStat(Int32[6],Float32[-833.3333])
#   [:ϕ2_F1,:LD3,:ϕ1_RD3,:ϕ… => StateStat(Int32[6],Float32[-500.0])
#   [:ϕ2_RX2,:ϕ2_F0,:ϕ2_F1,… => StateStat(Int32[0],Float32[0.0])
#   [:LD2,:ϕ1_F1,:R,:ϕ1_RD2] => StateStat(Int32[4,2,4],Float32[-750.0,-1000.0,-75…
#   [:ϕ2_LB1,:ϕ2_F1,:ϕ1_RD2… => StateStat(Int32[5],Float32[-1000.0])
#   [:ϕ1_RD3,:ϕ2_U1,:LArr,:… => StateStat(Int32[0,0,0,0,0,0],Float32[0.0,0.0,0.0,…
#   [:RX1,:RB1,:RDep,:F1]    => StateStat(Int32[2,1,1],Float32[0.0,0.0,0.0])
#   [:ϕ1_U2,:ϕ2_RB2,:ϕ3_U1,… => StateStat(Int32[12],Float32[-666.6667])
#   [:U1,:ϕ1_LD2,:RD0,:GO]   => StateStat(Int32[0,0,0,0],Float32[0.0,0.0,0.0,0.0])
#   [:LX2,:LB1,:RD1,:U1]     => StateStat(Int32[1,1,0,0],Float32[0.0,-1000.0,0.0,…
#   [:ϕ1_RD2,:ϕ2_LD1,:ϕ3_U1… => StateStat(Int32[6],Float32[-333.33334])
#   [:ϕ2_U1,:ϕ2_LD3,:ϕ2_RD2… => StateStat(Int32[7],Float32[-285.7143])
#   [:ϕ1_RD3,:ϕ1_RB1,:ϕ3_LD… => StateStat(Int32[0],Float32[0.0])
#   [:ϕ3_LB1,:RD2,:RD1,:ϕ3_… => StateStat(Int32[2,3,1],Float32[-1000.0,-666.6667,…
#   [:ϕ2_F1,:ϕ1_LD2,:RB2,:ϕ… => StateStat(Int32[0],Float32[0.0])
#   [:R,:LD3,:ϕ2_LX2,:ϕ3_F1] => StateStat(Int32[1],Float32[-1000.0])
#   [:ϕ2_RX1,:ϕ2_LD1,:LB2,:… => StateStat(Int32[0,0,0,0],Float32[0.0,0.0,0.0,0.0])
#   [:ϕ2_RD3,:ϕ3_LX2,:ϕ1_F0… => StateStat(Int32[0],Float32[0.0])
#   [:R,:RD3,:RD3,:LB1]      => StateStat(Int32[0],Float32[0.0])
#   [:ϕ3_LD0,:ϕ1_RX1,:F0,:ϕ… => StateStat(Int32[0],Float32[0.0])
#   [:U1,:ϕ1_GO,:ϕ2_F1,:RD1] => StateStat(Int32[1,1,1,1],Float32[-1000.0,0.0,0.0,…
#   [:ϕ2_RD1,:ϕ3_F0,:ϕ2_F1,… => StateStat(Int32[0],Float32[0.0])
#   [:ϕ1_LX2,:F0,:ϕ2_RD1,:ϕ… => StateStat(Int32[5],Float32[-400.0])
#   [:ϕ3_RD2,:F1,:ϕ2_RD2,:ϕ… => StateStat(Int32[0,0,0],Float32[0.0,0.0,0.0])
#   ⋮                        => ⋮

# %%
# fig, axes = plt.subplots(nrows=2, ncols=1, sharex=true, sharey=true, figsize=(8,8.5))
# #fig[:subplots_adjust](hspace=1)


# betaIdx = 1;
# k = 0
# for atcType in [:MDP_periodic, :None]    
#     k += 1
#     PyPlot.subplot(2,1,k)
#     Y = collisionPos[atcType][betaIdx,:,1]
#     X = collisionPos[atcType][betaIdx,:,2]
#     X = X[!isnan(X)]; Y = Y[!isnan(Y)]
#     matrix = PyPlot.hist2D(X,Y,bins=[15,10]*6,cmin=1, norm=plt.matplotlib[:colors][:LogNorm]());#,color=colors[k],normed=true)#Y,linestyle="", marker=".",markersize=2,color=colors[k])    
    
#     ax = PyPlot.gca();
#     # #PyPlot.axis("equal")
#     PyPlot.ylabel("North")
#     k == 2 && PyPlot.xlabel("East")
#     PyPlot.xlim([-6000, 6000])
#     PyPlot.ylim([-2000, 2000])
#     #ax[:set_aspect](1.5)    
#     PyPlot.grid("on")
#     PyPlot.title(k == 1 ? "auto-ATC" : "silent ATC",loc="left",fontsize=14)
# end

# cax = plt.axes([0.925, 0.1, 0.03, .8])
# PyPlot.colorbar(ax=axes,cax=cax, use_gridspec=false,orientation="vertical")#, pad=.1, anchor=(6, 6.0))
# #plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/collision_location.pgf", bbox_inches="tight")

# %%
# histData_x = Vector{Float64}[]
# histData_y = Vector{Float64}[]

# for b in 1:size(tStat,1)
#     for k in 1:size(tStat,2)
#         tS_ = tStat[b,k,:] #Float64[x > 3600*20 ? NaN : x for x in tStat[b,k,:]];
#         tS_ = tS_[!isnan(tS_)]/3600
#         data = PyPlot.hist(tS_,1000, histtype="step", cumulative=true, normed=true, align="right")
#         push!(histData_x, [0, data[2][1:end-1]]) #x-data
#         push!(histData_y, [0, data[1]]) #y-data
#     end
# end
# PyPlot.clf();


# #beta = 0.01 {MDP, MDP2, None}
# #beta = 0.5 {MDP, MDP2, None}

# #green, green --, blue
# #red, red --, blue

# #None: Blue, Blue --
# #beta = 0.01: Green, Green --
# #beta = 0.5: Red, Red --

# betaColors = ["g", "r", "b", "c"]
# assert(length(betaColors) == NbetaVals)
# colors = vcat([[c,"k"] for c in betaColors]...)

# linestyles = ["-","--","-"]#, "-","--","-"]

# betaValStr = [string(β) for β in betaVals]
# legends = ["auto-ATC: event-driven, \$\\beta\$="*betaValStr[1], "silent ATC",           
#            "auto-ATC: event-driven, \$\\beta\$="*betaValStr[2], #skipped
#            "auto-ATC: event-driven, \$\\beta\$="*betaValStr[3],#skipped
#            "auto-ATC: event-driven, \$\\beta\$="*betaValStr[4]]#skipped]
    
# idx = 0
# for b in 1:size(tStat,1) #different betas 0, 0.01 , 0.5, etc
#     for k in 1:size(tStat,2) #different policies  MDP(, MDP2 (green), None (blue)
#         idx += 1
#         if atcTypes[k] == :None && b > 1
#             continue
#         end
#         PyPlot.plot(histData_y[idx],histData_x[idx], color = colors[idx], linestyle="-") #linestyles[(idx-1)%2 + 1])
#     end
# end

# PyPlot.grid("on")
# PyPlot.ylabel("Time to first NMAC (hours)")
# PyPlot.xlabel("Probability")
# PyPlot.xlim([0,1])
# PyPlot.ylim([0,20])

# ax = PyPlot.gca();
# #ax[:set_aspect](1/40.);
# leg = PyPlot.legend(legends,bbox_to_anchor=(0.5, 1.25), loc = 9, ncol=3, fontsize=12, numpoints=3)
# # set the linewidth of each legend object
# for legobj in leg[:legendHandles]
#     legobj[:set_linewidth](2.0)
# end
# # plt.savefig("./results/CTMDP_2phases_cdf.pdf", bbox_inches="tight")

# %%
# alertRates = similar(tStat)
# #First axis of tStat is beta, second axis is ATC type (MDP, MDP_period, NONE)
# for b in 1:size(tStat,1)
#     for k in 1:size(tStat,2)
#         tS_minutes = tStat[b,k,:]/60.
#         alertRates[b, k, :] = alertCounts[b,k,:] ./ tS_minutes
#     end
# end

# boxData = {alertRates[b,1,:][:] for b in 1:NbetaVals}
# push!(boxData, alertRates[1,end,:][:])
# PyPlot.boxplot(boxData)

# PyPlot.ylim([-0.05,2.0])
# PyPlot.ylabel("Intervention rate (commands / minute)")

# xLabels = ["auto-ATC \$\\beta\$="*betaValStr[b] for b in 1:NbetaVals]
# push!(xLabels,"silent-ATC")


# PyPlot.xticks(1:(NbetaVals+1), xLabels)
# PyPlot.grid("on")

# # plt.savefig("./results/CTMDP_2phases_alert_rate.pdf", bbox_inches="tight")

# %%
# #First axis is betas, second axis is atc type (MDP, MDP_perio, NONE)
# boxData = {flightTimes[b,1,:][:]/3600 for b in 1:NbetaVals}
# push!(boxData, flightTimes[1,end,:][:]/3600)
# PyPlot.boxplot(boxData)


# PyPlot.ylim([-0.05,10])
# PyPlot.ylabel("Flight Hours Before NMAC")
# PyPlot.xticks(1:(NbetaVals+1), xLabels)
# PyPlot.grid("on")
# #plt.savefig("./results/CTMDP_4phases_flight_hours.pgf", bbox_inches="tight")

# %%
# boxData = {nNMACcounts[b,1,:][:] for b in 1:NbetaVals}
# push!(boxData, nNMACcounts[1,end,:][:])
# boxData = boxData / (tBatchTime/3600)
# PyPlot.boxplot(boxData)


# xLabels = ["auto-ATC \$\\beta\$="*betaValStr[b] for b in 1:NbetaVals]
# push!(xLabels,"silent-ATC")
# PyPlot.ylim([0, 2])
# #PyPlot.ylabel("NMACs per hour")
# PyPlot.xticks(1:(NbetaVals+1), xLabels)
# PyPlot.grid("on")
# #plt.savefig("./results/NMACSperhour.pdf", bbox_inches="tight")

# %%
@time save("./results/"*policy_prefix*"new_3DSimResults_n"*string(pattern.nPhases)*".jld", 
"tStat", tStat, "alertCounts", alertCounts, 
"flightTimes", flightTimes, "tTotals", tTotals, "nNMACcounts", nNMACcounts);
# Out:
# elapsed time: 0.
# 537552525 seconds (10556556 bytes allocated)

# %%
pattern.nPhases
# Out:
# 6

# %%
"./results/"*policy_prefix*"new_3DSimResults_n"*string(pattern.nPhases)*".jld"
# Out:
# "./results/greedyRandom_new_3DSimResults_n6.jld"
