# %%
solveAll = false; 
include("pattern.jl");
# Out:
# Defining states
# elapsed time:
# 0.939928029 seconds
# Defining permutations/actions
# elapsed time:
# 35.192191284 seconds

# %%
α = 0.95; β = 0.01
@time data = load("a_0.95_b_0.01.jld"); Pistar = data["Pistar"];
#@time data = load("simple_policy.jld"); PiSimple = data["PiSimple"];
# Out:
# elapsed time:
# 1.67286411 seconds (51103880 bytes allocated, 28.61% gc time)

# %%
if isdefined(current_module(),:LastMain) && isdefined(LastMain,:PyPlot)
  using LastMain.PyPlot
else
  using PyPlot
end
linewidth = 0.4
plt.rc("axes", linewidth=linewidth)
plt.rc("font", family="")
plt.rc("axes", titlesize="medium", labelsize="medium")
plt.rc("xtick", labelsize="small")
plt.rc("xtick.major", width=linewidth/2)
plt.rc("ytick", labelsize="small")
plt.rc("ytick.major", width=linewidth/2)
plt.rc("legend", fontsize="large")
plt.rc("axes" ,unicode_minus=false)
# Out:
# INFO: Loading help data...

# %%
include("3dsim.jl"); #srand(5);

# %%
aircraftList = [airplane(50,:LB1), airplane(50, :R), airplane(50, :U1), airplane(50, :LX1)];

# %%
(idmin, tmax) = simulate!(aircraftList,3600,true,:MDP,true); tmax
# Out:
# 2418.0

# %%
roff = 2*4;
b=0
g=0
rstart = 20*4+roff;
rlen = 100
range = rstart:(rstart+rlen)
range=1:length(aircraftList[1].path)
make3d = true

if(make3d)
    ax = PyPlot.gca(projection="3d")
    #ax[:view_init](0, 180)
    ax[:pbaspect] = [1,1,0.6]   
else
    ax = PyPlot.gca()
end

D3 = Vector{Float64}[]
for ac in aircraftList
    Y = [p.n for p in ac.path[range]];
    X = [p.e for p in ac.path[range]];
    Z = -[p.d for p in ac.path[range]];
    N = length(X)
    if(make3d)
        di = 100
        for i in 1:di:(N-di)
            idx = i:(i+di)
            r = clip( mean(Z[idx]) / 300 , .05, 1.)    
            PyPlot.plot3D(Y[idx],X[idx],Z[idx],color=(r,g,0))
        end
        push!(D3, [Y[end], X[end], Z[end]])
        PyPlot.xlabel("North")
        PyPlot.ylabel("East")
        PyPlot.zlabel("Altitude")
    else
        PyPlot.plot(X,Y)
        PyPlot.axis("equal")
        PyPlot.ylabel("North")
        PyPlot.xlabel("East")
    end
    g += 0.25
end

for d in D3
    PyPlot.scatter3D(d[1],d[2],d[3],marker="o")         
end
PyPlot.grid("on")
if make3d
    ax[:set_ylim3d]([-5000, 5000])
end
#ax[:set_xlim3d]([-6000, 6000])

#plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/3dpattern.pdf", bbox_inches="tight")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f121b3ee150>)
# (-5000,5000)

# %%
function randomStart()
    rstart_in = ()-> [airplane(46 + (rand()-0.5)*3,s) for s in allstates[rand(3:length(allstates), 4)]];
    acList = rstart_in()
    
    notok = (ACLIST)-> getDmin(ACLIST)[1] <=  0
    
    
    while(notok(acList))
        acList = rstart_in()
    end
    return acList
end
# Out:
# randomStart (generic function with 1 method)

# %%
#startSates = rstart_()
sStart = [:T, :T, :T, :T]
N = 1000
#atcStat = zeros(N,2)
tStat = zeros(N,3)
collisionPos = {:MDP=> zeros(N,3), :MDP2=> zeros(N,3), :None=> zeros(N,3)}

stop = false
@time for i in 1:N
    if stop
        break
    end
    atcIdx = 0
    for atcType in [:MDP, :MDP2, :None]        
        atcIdx += 1       
        aircraftList = randomStart()
        sStart = [ac.navDest[1] for ac in aircraftList]
        #srand(3)
        (idmin, tmax) = simulate!(aircraftList,3600*20,true,atcType,false);
        
        collisionPos[atcType][i,:] = Float64[NaN, NaN, NaN]
        if !(0 in idmin)
            collisionPos[atcType][i,:] = [aircraftList[idmin[1]].posNED.n, aircraftList[idmin[1]].posNED.e, aircraftList[idmin[1]].posNED.d]
        end
        
        if(tmax == 0)
            stop = true
            println("This shouldn't happen!")
            break
        elseif(tmax !=3600 && atcType == :MDP)
             #stop = true
             #break
        end
        
        #atcStat[i, hasATC ? 1 : 2] = sum([a <= 0 for a in RNMAC_min])
        tStat[i, atcIdx] = tmax
    end
end
# Out:
# elapsed time: 486
# .916263887 seconds (35281685292 bytes allocated, 76.51% gc time)

# %%
# Out:
# fn (generic function with 1 method)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=true, sharey=true)
k = 0
for atcType in [:MDP, :None]    
    k += 1
    PyPlot.subplot(2,1,k)
    Y = collisionPos[atcType][:,1]
    X = collisionPos[atcType][:,2]
    X = X[!isnan(X)]; Y = Y[!isnan(Y)]
    matrix = PyPlot.hist2D(X,Y,bins=[15,10]*6,cmin=1, norm=plt.matplotlib[:colors][:LogNorm]());#,color=colors[k],normed=true)#Y,linestyle="", marker=".",markersize=2,color=colors[k])    
    
    ax = PyPlot.gca();
    # #PyPlot.axis("equal")
    PyPlot.ylabel("North")
    k == 2 && PyPlot.xlabel("East")
    PyPlot.xlim([-6000, 6000])
    PyPlot.ylim([-2000, 2000])
    ax[:set_aspect](1)    
    PyPlot.grid("on")
    PyPlot.title(k == 1 ? "auto-ATC" : "baseline ATC",loc="left",fontsize=14)
end

cax = plt.axes([0.95, 0.1, 0.03, .8])
PyPlot.colorbar(ax=axes,cax=cax, use_gridspec=true,orientation="vertical")#, pad=.1, anchor=(6, 6.0))
plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/collision_location.pgf", bbox_inches="tight")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f121a4b0c10>)

# %%
histData_x = Vector{Float64}[]
histData_y = Vector{Float64}[]
for k in 1:size(tStat,2)
    tS_ = tStat[:, k]#Float32[x == 3600 ? NaN : x for x in tStat[:,k]];
    tS_ = tS_[!isnan(tS_)]/3600
    data = PyPlot.hist(tS_,1000, histtype="step", cumulative=true, normed=true, align="right")
    push!(histData_x, [0, data[2][1:end-1]]) #x-data
    push!(histData_y, [0, data[1]]) #y-data
end
PyPlot.clf();

colors = ["r","g","b"]
for k in 1:size(tStat,2)
    PyPlot.plot(histData_y[k],histData_x[k],color=colors[k])
end

PyPlot.grid("on")
PyPlot.ylabel("Time to first NMAC (hours)")
PyPlot.xlabel("probability")
PyPlot.xlim([0,1])
PyPlot.ylim([0,20])
PyPlot.legend(["auto-ATC: event-driven","auto-ATC: periodic", "baseline ATC"],bbox_to_anchor=(0.6, 0.9), loc = 1)
plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/cdf_8hours.pgf", bbox_inches="tight")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f121a8f81d0>)

# %%
colors = ["r","b"]
k = 0
for atcType in  [:MDP, :None]
    k += 1
    X = collisionPos[atcType][:,2]
    Y = collisionPos[atcType][:,1]
    PyPlot.plot(X,Y,linestyle="", marker=".",markersize=2,color=colors[k])
end
ax = PyPlot.gca();
#PyPlot.axis("equal")
PyPlot.ylabel("North")
PyPlot.xlabel("East")
#PyPlot.xlim([-7000, 7000])
PyPlot.ylim([-2000, 2000])
ax[:set_aspect](1)
PyPlot.grid("on")
PyPlot.legend(["optimized ATC","NO ATC"],bbox_to_anchor=(0.0, 1.4), loc=2, ncol = 2)


s = :R
x= posNE[(s,"S")].e
y= posNE[(s,"S")].n
PyPlot.text(x, y, s, fontsize=10, bbox={"facecolor" => "white", "alpha"=>0.4})

#plt.savefig("/home/zouhair/Dropbox/AA229/project/ATMS2015/collision_location.pgf", bbox_inches="tight")
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/lines.py:503: RuntimeWarning: invalid value encountered in greater_equal
#   return np.alltrue(x[1:] - x[0:-1] >= 0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f121b715c90>)
# PyObject <matplotlib.text.Text object at 0x7f121adfbf10>
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)
