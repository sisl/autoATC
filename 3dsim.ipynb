# %%
#This should take about ~4-5 minutes
solveAll = false; 
include("pattern.jl");
# Out:
# Defining states
# elapsed time:
# 1.197340404 seconds

# %%
@time data = load("/home/zouhair/left-or-right/a_1.0_b_0.01.jld"); Pistar = data["Pistar"];
@time data = load("/home/zouhair/left-or-right/simple_policy.jld"); PiSimple = data["PiSimple"];
# Out:
# elapsed time:
# 1.746486599 seconds (51035804 bytes allocated)
# elapsed time: 0.003174972 seconds (4262124 bytes allocated)

# %%
if isdefined(current_module(),:LastMain) && isdefined(LastMain,:PyPlot)
  using LastMain.PyPlot
else
  using PyPlot
end
# Out:
# INFO: Loading help data...

# %%
include("3dsim.jl"); #srand(5);

# %%
aircraftList = [airplane(50,:LDep), airplane(50, :RArr), airplane(50, :LX1), airplane(50, :U1)];

# %%
(RNMAC, tmax) = simulate!(aircraftList,3600,false,:MDP,true); tmax
# Out:
# 3600.0

# %%
RNMAC_min = min(RNMAC[:,1], RNMAC[:,2],  RNMAC[:,3],  RNMAC[:,4]) - 100;

# %%
idx =  1:length(aircraftList[1].path)

PyPlot.plot(RNMAC_min)
PyPlot.grid("on")
PyPlot.ylim([-10, 500])

# %%
roff = 2*4;
b=0
g=0
rstart = 20*4+roff;
rlen = 100
range = rstart:(rstart+rlen)
range=1:length(aircraftList[1].path)
for ac in aircraftList
    Y = [p.n for p in ac.path[range]];
    X = [p.e for p in ac.path[range]];
    Z = -[p.d for p in ac.path[range]];
    N = length(X)
    if(false)
        di = 100
        for i in 1:di:(N-di)
            idx = i:(i+di)
            r = max( mean(Z[idx]) / 300 , .05)    
            PyPlot.plot3D(X[idx],Y[idx],Z[idx],color=(r,g,0))
        end
        PyPlot.scatter3D(X[end],Y[end],Z[end],marker="x")
        ax = PyPlot.gca()
        ax[:view_init] = [90, 30]
        ax[:pbaspect] = [1,1,1/2]    

    else
        PyPlot.plot(X,Y)
    end
    g += 0.25
end
PyPlot.axis("equal")
PyPlot.grid("on")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fdc41558f10>)

# %%
[ac.navDest for ac in rstart_()]

# %%
function randomStart()
    rstart_in = ()-> [airplane(50,s) for s in allstates[rand(3:length(allstates), 4)]];
    acList = rstart_in()
    
    notok = (ACLIST)-> minimum([getDmin(ACLIST, i) for i in 1:4]) <=  0
    
    
    while(notok(acList))
        acList = rstart_in()
    end
    return acList
end
# Out:
# randomStart (generic function with 1 method)

# %%
#startSates = rstart_()
sStart = [:T, :T, :T, :T]
N = 100
#atcStat = zeros(N,2)
tStat = zeros(N,3)
stop = false
@time for i in 1:N
    if stop
        break
    end
    atcIdx = 0
    for atcType in [:MDP, :Greedy, :None]        
        atcIdx += 1       
        aircraftList = randomStart()
        sStart = [ac.navDest[1] for ac in aircraftList]
        #srand(3)
        (RNMAC, tmax) = simulate!(aircraftList,3600*8,true,atcType,false);
        #RNMAC_min = min(RNMAC[:,1], RNMAC[:,2],  RNMAC[:,3],  RNMAC[:,4]) - 100;
        
        if(tmax == 0)
            stop = true
            break
        elseif(tmax !=3600 && atcType == :MDP)
             #stop = true
             #break
        end
        
        #atcStat[i, hasATC ? 1 : 2] = sum([a <= 0 for a in RNMAC_min])
        tStat[i, atcIdx] = tmax
    end
end

# %%
#sStart

# %%
for k in size(tStat,2)
    tS_ = tStat[:, k]#Float32[x == 3600 ? NaN : x for x in tStat[:,k]];
    tS_ = tS_[!isnan(tS_)]/3600
    PyPlot.hist(tS_,1000, histtype="step", cumulative=true, normed=true)
end
PyPlot.grid("on")
PyPlot.xlabel("Time to 1st NMAC (hours)")
PyPlot.ylabel("CDF")
#PyPlot.ylim([0,1.2])
PyPlot.legend(["optimized ATC", "(greedy) ATC", "NO ATC"])

# %%
include("3dsim.jl"); #srand(5);

# %%
srand(3)
sStart = [:LB1, :LX2, :GO, :U1];
aircrafList = [airplane(50, s) for s in sStart]
(RNMAC, tmax) = simulate!(aircrafList,3600,true,:MDP,false); tmax
# Out:
# 896.75

# %%
validActions([:LB1, :LX2, :GO, :LD2])
# Out:
# 3-element Array{(Int64,Symbol),1}:
#  (0,:∅)
#  (4,:LB1)
#  (4,:LD3)
