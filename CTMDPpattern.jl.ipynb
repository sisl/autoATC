# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
legalActions = validCompactActions
# Out:
# validCompactActions (generic function with 1 method)

# %%
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
Aj = (Vector{Int64})[[a, [0 for i in 1:(g_nVehicles-1)]] for a in A ];

# %%
P0 = spzeros(g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])        
        end
    end
end

# %%
M0 = speye(g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./teaTime[s]
end

# %%
# M = (Symbol => typeof(M0))[a => copy(M0) for a in [:∅, :S]];
# M[:S] *= 0.5;  #Slower means longer lingering time, i.e. lower reciprocals

# %%
Isp = spdiagm(ones(g_nNodes));

# %%
#Note that we are using the TRANSPOSE!!
#Also notice how we are indexing into P using a+1
#the joys of 1-based indexing :(
Qt = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
As = Qt[1]; AAs = kronSum(As,As);
A = full(As); AA = full(AAs);

# %%
using Gadfly
# Out:
# Warning: using StatsBase.sample in module Main conflicts with an existing identifier.
# Warning: using StatsBase.midpoints in module Main conflicts with an existing identifier.
# Warning: using StatsBase.histrange in module Main conflicts with an existing identifier.
# Warning: using Gadfly.Stat in module Main conflicts with an existing identifier.

# %%
spy(As)
# Out:
# Plot(...)

# %%
Vs = V; Vs[find(x-> abs(x) < 1e-6, V)] = 0; Vs = sparse(Vs)
# Out:
# 27x27 sparse matrix with 498 Complex{Float64} entries:
# 	[1 ,  1]  =  -0.197689-0.0282402im
# 	[2 ,  1]  =  0.427984+0.0im
# 	[3 ,  1]  =  -0.387763-0.027538im
# 	[4 ,  1]  =  0.198614+0.21569im
# 	[5 ,  1]  =  -0.187538-0.300956im
# 	[6 ,  1]  =  0.0515967+0.130671im
# 	[7 ,  1]  =  0.0392673-0.0984192im
# 	[8 ,  1]  =  -0.196241+0.270724im
# 	[9 ,  1]  =  0.198614+0.21569im
# 	[10,  1]  =  -0.187538-0.300956im
# 	⋮
# 	[4 , 27]  =  0.0324604+0.0im
# 	[7 , 27]  =  -0.0373046+0.0im
# 	[9 , 27]  =  -0.0991762+0.0im
# 	[12, 27]  =  -0.14595+0.0im
# 	[15, 27]  =  0.0973811+0.0im
# 	[16, 27]  =  -0.129841+0.0im
# 	[18, 27]  =  -0.221315+0.0im
# 	[19, 27]  =  0.73302+0.0im
# 	[20, 27]  =  -0.297529+0.0im
# 	[21, 27]  =  0.396705+0.0im
# 	[23, 27]  =  -0.32845+0.0im

# %%
Vs' * Vs
# Out:
# 27x27 sparse matrix with 729 Complex{Float64} entries:
# 	[1 ,  1]  =  1.0+0.0im
# 	[2 ,  1]  =  0.169182+0.318741im
# 	[3 ,  1]  =  0.206828-0.157942im
# 	[4 ,  1]  =  -0.127591-0.18225im
# 	[5 ,  1]  =  0.077418+0.106393im
# 	[6 ,  1]  =  0.123186-0.121547im
# 	[7 ,  1]  =  -0.344023+0.0490384im
# 	[8 ,  1]  =  0.0614848-0.0586468im
# 	[9 ,  1]  =  -0.0764456+0.170624im
# 	[10,  1]  =  -0.222743-0.0240588im
# 	⋮
# 	[17, 27]  =  -0.0158581-2.43178e-9im
# 	[18, 27]  =  -0.0489256+0.0im
# 	[19, 27]  =  0.0489256+0.0im
# 	[20, 27]  =  -0.0125109+0.0im
# 	[21, 27]  =  0.0239561+1.09197e-9im
# 	[22, 27]  =  0.0239561-1.09197e-9im
# 	[23, 27]  =  -0.300952+0.0im
# 	[24, 27]  =  -0.167109+0.0im
# 	[25, 27]  =  -0.743435+0.0im
# 	[26, 27]  =  -0.312393+0.0im
# 	[27, 27]  =  1.0+0.0im

# %%
Q, V = eig(A); QQ, VV = eig(AA);

# %%
sort(QQ, lt = (x,y) -> abs(x) < abs(y))
# Out:
# 729-element Array{Complex{Float64},1}:
#  4.78937e-15+0.0im
#         -0.1+0.0im
#         -0.1+0.0im
#    -0.114625+0.0im
#    -0.114625+0.0im
#    -0.157467+0.0im
#    -0.157467+0.0im
#         -0.2+0.0im
#    -0.214625+0.0im
#    -0.214625+0.0im
#    -0.229251+0.0im
#    -0.257467+0.0im
#    -0.257467+0.0im
#             ⋮
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.64329+0.0im
#     -4.64329+0.0im
#     -4.64329-0.606161im
#     -4.64329+0.606161im

# %%
sort([x[1] + x[2] for x in collect(product(Q, Q))], lt = (x,y) -> abs(x) < abs(y))
# Out:
# 729-element Array{Any,1}:
#  1.68048e-15+0.0im
#         -0.1+0.0im
#         -0.1+0.0im
#    -0.114625+0.0im
#    -0.114625+0.0im
#    -0.157467+0.0im
#    -0.157467+0.0im
#         -0.2+0.0im
#    -0.214625+0.0im
#    -0.214625+0.0im
#    -0.229251+0.0im
#    -0.257467+0.0im
#    -0.257467+0.0im
#             ⋮
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.32164+0.303081im
#     -4.32164-0.303081im
#     -4.64329+0.0im
#     -4.64329+0.0im
#     -4.64329+0.606161im
#     -4.64329-0.606161im

# %%
Qt_joint = (typeof(M0))[kronSum([Qt[an+1] for an in a]) for a in Aj];

# %%
sizeof(Qt_joint[2].nzval)/1e6
# Out:
# 27.398736

# %%
Vshort = ones(length(g_Scomp));

# %%
Aopt = gaussSeidel!(Vshort,1.2)# at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:268
Vshort
# Out:
# At iteration #5
#  (14.12 sec)
# At iteration #
# 10 (27.97 sec)
# At iteration #
# 15 (41.67 sec)
# At iteration #
# 20 (55.52 sec)
# Stopping after
# 21 iterations (maxVchange = 0.71)
# elapsed time: 58.255567285 seconds (20066311556 bytes allocated, 20.47% gc time)
# 27405-element Array{Float64,1}:
#   -71.5136
#   -96.0319
#   -52.867
#   -49.9369
#   -49.9538
#   -50.4722
#   -57.051
#   -59.4049
#   -49.9517
#   -49.9672
#   -50.4878
#   -57.0649
#   -54.3043
#     ⋮
#    -8.78317
#   -18.0367
#   -43.1223
#    -2.36677
#    -7.54136
#   -21.8241
#   -77.1502
#    -1.88741
#    -5.82039
#   -20.9792
#   -76.7654
#  -164.86

# %%
unique(Aopt)
# Out:
# 13-element Array{Array{Int64,1},1}:
#  [0,0]
#  [4,1]
#  [4,2]
#  [3,1]
#  [3,2]
#  [3,3]
#  [4,3]
#  [2,2]
#  [2,1]
#  [2,3]
#  [1,2]
#  [1,1]
#  [1,3]

# %%
popo = [CIDX2S(cidx) => policy_S2a(CIDX2S(cidx),Aopt) for cidx in find(x-> x != g_noaction, Aopt)]
# Out:
# Dict{Array{Symbol,1},Union(Array{Int64,1},(Int64,Any))} with 378 entries:
#   [:RD0,:RDep] => (0,:∅)
#   [:LB1,:RD3]  => (0,:∅)
#   [:RD2,:LD0]  => (0,:∅)
#   [:LX1,:RB2]  => (0,:∅)
#   [:RD2,:GO]   => (0,:∅)
#   [:RB1,:LArr] => (0,:∅)
#   [:GO,:RD0]   => (0,:∅)
#   [:LB2,:RD0]  => (0,:∅)
#   [:R,:LD2]    => (0,:∅)
#   [:T,:LB2]    => (0,:∅)
#   [:LD2,:RX1]  => (0,:∅)
#   [:LB1,:F1]   => (0,:∅)
#   [:LD2,:LD2]  => (0,:∅)
#   [:LX1,:RX2]  => (0,:∅)
#   [:RD3,:RB2]  => (0,:∅)
#   [:LB2,:RDep] => (0,:∅)
#   [:LD2,:RD3]  => (1,:LB1)
#   [:RB1,:RDep] => (0,:∅)
#   [:LD3,:LB2]  => (0,:∅)
#   [:T,:RD3]    => (0,:∅)
#   [:RB1,:LDep] => (0,:∅)
#   [:F1,:F0]    => (0,:∅)
#   [:T,:LX1]    => (0,:∅)
#   [:LB1,:LX2]  => (0,:∅)
#   [:T,:LD2]    => (0,:∅)
#   ⋮            => ⋮

# %%
for k in keys(popo)
    if popo[k] != g_noaction
        println(k, popo[k])
    end
end
# Out:
# [:
# LD2,:RD3](1,:LB1)
# [:RB2,:LArr](2,:LD1)
# [:U1,:RD1](1,:LX1)
# [:U1,:LX2](1,:RX1)
# [:F1,:GO](1,:R)
# [:U2,:RX2](1,:LX2)
# [:LB2,:RArr](2,:RD1)
# [:U2,:RD0](1,:LX2)
# [:RD0,:RArr](2,:RD3)
# [:LD2,:RB2](1,:LB1)
# [:RD3,:RArr](2,:RD1)
# [:U1,:U2](1,:LX1)
# [:U1,:RX2](1,:LX1)
# [:LD2,:LB1](1,:LD3)
# [:LX1,:LArr](2,:LD3)
# [:RD2,:LD3](1,:RB1)
# [:LD1,:LArr](2,:LD3)
# [:RD2,:LB2](1,:RB1)
# [:U1,:LD2](1,:U2)
# [:T,:R](2,:U1)
# [:RD2,:RB2](1,:RB1)
# [:RD2,:RB1](1,:RD3)
# [:LD2,:LB2](1,:LB1)
# [:R,:U1](1,:T)
# [:LB1,:RD2](2,:RD3)
# [:U1,:RX1](1,:LX1)
# [:LX1,:U2](2,:RX2)
# [:LD1,:U2](2,:RX2)
# [:RD1,:U2](2,:LX2)
# [:R,:F1](2,:GO)
# [:RD1,:RArr](2,:RD3)
# [:R,:R](1,:U1)
# [:F0,:LArr](2,:LD1)
# [:U1,:F1](2,:R)
# [:LD2,:RB1](1,:LD3)
# [:LX2,:LArr](2,:LD3)
# [:LB2,:LArr](2,:LD1)
# [:U1,:RD2](1,:U2)
# [:RX1,:RArr](2,:RD3)
# [:U2,:LD0](1,:RX2)
# [:F0,:RArr](2,:RD1)
# [:LD2,:F1](1,:LD3)
# [:F1,:RD2](2,:RD3)
# [:LD2,:LArr](2,:LD3)
# [:LD0,:LArr](2,:LD3)
# [:U1,:LD0](1,:RX1)
# [:LD3,:LArr](2,:LD1)
# [:RX2,:RArr](2,:RD3)
# [:U1,:LX1](1,:RX1)
# [:LD2,:LD3](1,:LB1)
# [:U2,:LX2](1,:RX2)
# [:RB2,:RArr](2,:RD1)
# [:U1,:RD0](1,:LX1)
# [:R,:RDep](1,:U1)
# [:RX1,:U2](2,:LX2)
# [:R,:LDep](1,:U1)
# [:RD2,:RArr](2,:RD3)
# [:U1,:LD1](1,:RX1)
# [:RD2,:RD3](1,:RB1)
# [:R,:GO](1,:T)

# %%
policy_S2a([:U2, :U1, :LX1, :LX1], Aopt)
# Out:
# (2,:RX1)

# %%
policy_S2a([:GO, :R], Aopt)
# Out:
# (2,:T)
