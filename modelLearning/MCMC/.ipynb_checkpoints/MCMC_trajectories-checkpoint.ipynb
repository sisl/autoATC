# %%
# %matplotlib inline
import pymc.Matplot as pymcPlt
import pymc
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import networkx as nx
matplotlib.rcParams['figure.figsize'] = (10,10)

# %%
np.set_printoptions(formatter={'float': '{: 0.3f}'.format})

# %%
itern = 0
while(itern < 20):
    try:
        import trajectories_MCMC as model
        print "success"
        break
    except:
        itern += 1
# Out:
# success

# %%
Mmap = pymc.MAP(model)
# Mmap.fit()
# Mmap.logp_at_max, Mmap.logp
# Out:
# Warning: Stochastic Sparsity's value is neither numerical nor array with floating-point dtype. Recommend fitting method fmin (default).
# /usr/local/lib/python2.7/dist-packages/pymc/NormalApproximation.py:337: RuntimeWarning: divide by zero encountered in log
#   self.data_len) - 2. * lnL  # k ln(n) - 2 ln(L)
# (-237830337.68891975, -237830337.68891975)

# %%
plt.plot(Mmap.xy_meas[:,0], Mmap.xy_meas[:,1], linestyle='', marker='.')

D = Mmap.xy_points.value
plt.plot(D[:,0], D[:,1], linestyle='', marker='.', color='r')

_x_nodes = np.array([n.value[0] for n in Mmap.xy_nodes])
_y_nodes = np.array([n.value[1] for n in Mmap.xy_nodes])
plt.plot(_x_nodes, _y_nodes, linestyle='', marker='x', color='g', markersize=8, markeredgewidth=3)
for (idx, (xt,yt)) in enumerate(zip(_x_nodes, _y_nodes)):
    plt.text(xt+.1,yt+.1,idx,size=15)

plt.grid("on")
plt.title("%.3f | %.2f"%(D.mean(), Mmap.logp))
plt.axis('equal')
# Out:
# (-10000.0, 15000.0, -8000.0, 8000.0)

# %%
M = pymc.MCMC(model)

# %%
M.sample(iter=1000,thin=10)#, burn=500, thin=50)
# Out:
#  [                  0%                  ] 3 of 1000 complete in 0.5 sec
#  [                  0%                  ] 5 of 1000 complete in 1.1 sec
#  [                  0%                  ] 7 of 1000 complete in 1.6 sec
#  [                  1%                  ] 10 of 1000 complete in 2.3 sec
#  [                  1%                  ] 13 of 1000 complete in 3.0 sec
#  [                  1%                  ] 16 of 1000 complete in 3.8 sec
#  [                  1%                  ] 18 of 1000 complete in 4.3 sec
#  [                  2%                  ] 21 of 1000 complete in 5.1 sec
#  [                  2%                  ] 24 of 1000 complete in 5.8 sec
#  [-                 2%                  ] 27 of 1000 complete in 6.5 sec
#  [-                 3%                  ] 30 of 1000 complete in 7.2 sec
#  [-                 3%                  ] 32 of 1000 complete in 7.7 sec
#  [-                 3%                  ] 34 of 1000 complete in 8.2 sec
#  [-                 3%                  ] 36 of 1000 complete in 8.8 sec
#  [-                 3%                  ] 38 of 1000 complete in 9.4 sec
#  [-                 4%                  ] 41 of 1000 complete in 10.2 sec
#  [-                 4%                  ] 43 of 1000 complete in 10.7 sec
#  [-                 4%                  ] 45 of 1000 complete in 11.3 sec
#  [-                 4%                  ] 48 of 1000 complete in 11.9 sec
#  [-                 5%                  ] 51 of 1000 complete in 12.6 sec
#  [--                5%                  ] 54 of 1000 complete in 13.3 sec
#  [--                5%                  ] 57 of 1000 complete in 14.0 sec
#  [--                6%                  ] 60 of 1000 complete in 14.7 sec
#  [--                6%                  ] 63 of 1000 complete in 15.4 sec
#  [-----------------62%---               ] 624 of 1000 complete in 147.4 sec
#  [-----------------62%---               ] 626 of 1000 complete in 147.9 sec
#  [-----------------62%---               ] 629 of 1000 complete in 148.6 sec
#  [-----------------63%----              ] 632 of 1000 complete in 149.3 sec
#  [-----------------63%----              ] 635 of 1000 complete in 150.0 sec
#  [-----------------63%----              ] 638 of 1000 complete in 150.8 sec
#  [-----------------64%----              ] 640 of 1000 complete in 151.3 sec
#  [-----------------64%----              ] 642 of 1000 complete in 151.8 sec
#  [-----------------64%----              ] 644 of 1000 complete in 152.3 sec
#  [-----------------64%----              ] 646 of 1000 complete in 152.8 sec
#  [-----------------64%----              ] 648 of 1000 complete in 153.4 sec
#  [-----------------65%----              ] 651 of 1000 complete in 154.1 sec
#  [-----------------65%----              ] 654 of 1000 complete in 154.8 sec
#  [-----------------65%----              ] 657 of 1000 complete in 155.5 sec
#  [-----------------66%-----             ] 660 of 1000 complete in 156.2 sec
#  [-----------------66%-----             ] 663 of 1000 complete in 156.9 sec
#  [-----------------66%-----             ] 665 of 1000 complete in 157.5 sec
#  [-----------------66%-----             ] 667 of 1000 complete in 158.2 sec
#  [-----------------66%-----             ] 669 of 1000 complete in 158.7 sec
#  [-----------------67%-----             ] 671 of 1000 complete in 159.2 sec
#  [-----------------67%-----             ] 674 of 1000 complete in 159.9 sec
#  [-----------------67%-----             ] 677 of 1000 complete in 160.6 sec
#  [-----------------68%-----             ] 680 of 1000 complete in 161.3 sec
#  [-----------------68%-----             ] 683 of 1000 complete in 162.0 sec
#  [-----------------68%------            ] 685 of 1000 complete in 162.5 sec
#  [-----------------68%------            ] 688 of 1000 complete in 163.2 sec
#  [-----------------69%------            ] 691 of 1000 complete in 163.9 sec
#  [-----------------69%------            ] 694 of 1000 complete in 164.6 sec
#  [-----------------69%------            ] 697 of 1000 complete in 165.3 sec
#  [-----------------70%------            ] 700 of 1000 complete in 166.0 sec
#  [-----------------70%------            ] 703 of 1000 complete in 166.7 sec
#  [-----------------70%------            ] 706 of 1000 complete in 167.4 sec
#  [-----------------70%------            ] 709 of 1000 complete in 168.1 sec
#  [-----------------71%-------           ] 712 of 1000 complete in 168.9 sec
#  [-----------------71%-------           ] 715 of 1000 complete in 169.6 sec
#  [-----------------71%-------           ] 718 of 1000 complete in 170.3 sec
#  [-----------------72%-------           ] 720 of 1000 complete in 170.8 sec
#  [-----------------72%-------           ] 722 of 1000 complete in 171.3 sec
#  [-----------------72%-------           ] 725 of 1000 complete in 172.1 sec
#  [-----------------72%-------           ] 728 of 1000 complete in 172.9 sec
#  [-----------------73%-------           ] 731 of 1000 complete in 173.6 sec
#  [-----------------73%-------           ] 733 of 1000 complete in 174.2 sec
#  [-----------------73%-------           ] 735 of 1000 complete in 174.9 sec
#  [-----------------73%--------          ] 737 of 1000 complete in 175.4 sec
#  [-----------------74%--------          ] 740 of 1000 complete in 176.1 sec
#  [-----------------74%--------          ] 742 of 1000 complete in 176.6 sec
#  [-----------------74%--------          ] 745 of 1000 complete in 177.4 sec
#  [-----------------74%--------          ] 747 of 1000 complete in 177.9 sec
#  [-----------------75%--------          ] 750 of 1000 complete in 178.6 sec
#  [-----------------75%--------          ] 753 of 1000 complete in 179.3 sec
#  [-----------------75%--------          ] 756 of 1000 complete in 180.0 sec
#  [-----------------75%--------          ] 759 of 1000 complete in 180.8 sec
#  [-----------------76%--------          ] 762 of 1000 complete in 181.5 sec
#  [-----------------76%---------         ] 765 of 1000 complete in 182.2 sec
#  [-----------------76%---------         ] 768 of 1000 complete in 182.9 sec
#  [-----------------77%---------         ] 771 of 1000 complete in 183.6 sec
#  [-----------------77%---------         ] 773 of 1000 complete in 184.1 sec
#  [-----------------77%---------         ] 775 of 1000 complete in 184.6 sec
#  [-----------------77%---------         ] 778 of 1000 complete in 185.3 sec
#  [-----------------78%---------         ] 781 of 1000 complete in 186.0 sec
#  [-----------------78%---------         ] 783 of 1000 complete in 186.5 sec
#  [-----------------78%---------         ] 786 of 1000 complete in 187.3 sec
#  [-----------------78%---------         ] 789 of 1000 complete in 187.9 sec
#  [-----------------79%----------        ] 792 of 1000 complete in 188.8 sec
#  [-----------------79%----------        ] 794 of 1000 complete in 189.3 sec
#  [-----------------79%----------        ] 796 of 1000 complete in 189.8 sec
#  [-----------------79%----------        ] 798 of 1000 complete in 190.4 sec
#  [-----------------80%----------        ] 800 of 1000 complete in 191.0 sec
#  [-----------------80%----------        ] 803 of 1000 complete in 191.6 sec
#  [-----------------80%----------        ] 806 of 1000 complete in 192.4 sec
#  [-----------------80%----------        ] 808 of 1000 complete in 192.9 sec
#  [-----------------81%----------        ] 810 of 1000 complete in 193.4 sec
#  [-----------------81%----------        ] 812 of 1000 complete in 194.3 sec
#  [-----------------81%----------        ] 814 of 1000 complete in 194.8 sec
#  [-----------------81%-----------       ] 816 of 1000 complete in 195.4 sec
#  [-----------------81%-----------       ] 818 of 1000 complete in 196.1 sec
#  [-----------------82%-----------       ] 820 of 1000 complete in 196.8 sec
#  [-----------------82%-----------       ] 822 of 1000 complete in 197.4 sec
#  [-----------------82%-----------       ] 824 of 1000 complete in 197.9 sec
#  [-----------------82%-----------       ] 827 of 1000 complete in 198.7 sec
#  [-----------------83%-----------       ] 830 of 1000 complete in 199.5 sec
#  [-----------------83%-----------       ] 832 of 1000 complete in 200.3 sec
#  [-----------------83%-----------       ] 835 of 1000 complete in 201.0 sec
#  [-----------------83%-----------       ] 838 of 1000 complete in 201.7 sec
#  [-----------------84%-----------       ] 841 of 1000 complete in 202.3 sec
#  [-----------------84%------------      ] 844 of 1000 complete in 203.0 sec
#  [-----------------84%------------      ] 847 of 1000 complete in 203.8 sec
#  [-----------------84%------------      ] 849 of 1000 complete in 204.5 sec
#  [-----------------85%------------      ] 851 of 1000 complete in 205.4 sec
#  [-----------------85%------------      ] 853 of 1000 complete in 206.2 sec
#  [-----------------85%------------      ] 856 of 1000 complete in 206.9 sec
#  [-----------------85%------------      ] 859 of 1000 complete in 207.6 sec
#  [-----------------86%------------      ] 862 of 1000 complete in 208.2 sec
#  [-----------------86%------------      ] 865 of 1000 complete in 208.9 sec
#  [-----------------86%------------      ] 868 of 1000 complete in 209.6 sec
#  [-----------------87%-------------     ] 871 of 1000 complete in 210.2 sec
#  [-----------------87%-------------     ] 874 of 1000 complete in 210.9 sec
#  [-----------------87%-------------     ] 877 of 1000 complete in 211.6 sec
#  [-----------------87%-------------     ] 879 of 1000 complete in 212.2 sec
#  [-----------------88%-------------     ] 881 of 1000 complete in 212.7 sec
#  [-----------------88%-------------     ] 883 of 1000 complete in 213.6 sec
#  [-----------------88%-------------     ] 885 of 1000 complete in 214.1 sec
#  [-----------------88%-------------     ] 888 of 1000 complete in 214.8 sec
#  [-----------------89%-------------     ] 890 of 1000 complete in 215.3 sec
#  [-----------------89%-------------     ] 892 of 1000 complete in 215.8 sec
#  [-----------------89%-------------     ] 894 of 1000 complete in 216.6 sec
#  [-----------------89%--------------    ] 896 of 1000 complete in 217.1 sec
#  [-----------------89%--------------    ] 899 of 1000 complete in 217.9 sec
#  [-----------------90%--------------    ] 902 of 1000 complete in 218.6 sec
#  [-----------------90%--------------    ] 904 of 1000 complete in 219.1 sec
#  [-----------------90%--------------    ] 906 of 1000 complete in 219.6 sec
#  [-----------------90%--------------    ] 908 of 1000 complete in 220.4 sec
#  [-----------------91%--------------    ] 910 of 1000 complete in 221.0 sec
#  [-----------------91%--------------    ] 913 of 1000 complete in 221.7 sec
#  [-----------------91%--------------    ] 915 of 1000 complete in 222.2 sec
#  [-----------------91%--------------    ] 917 of 1000 complete in 222.8 sec
#  [-----------------91%--------------    ] 919 of 1000 complete in 223.5 sec
#  [-----------------92%---------------   ] 922 of 1000 complete in 224.3 sec
#  [-----------------92%---------------   ] 925 of 1000 complete in 225.0 sec
#  [-----------------92%---------------   ] 927 of 1000 complete in 225.8 sec
#  [-----------------92%---------------   ] 929 of 1000 complete in 226.4 sec
#  [-----------------93%---------------   ] 931 of 1000 complete in 226.9 sec
#  [-----------------93%---------------   ] 933 of 1000 complete in 227.5 sec
#  [-----------------93%---------------   ] 935 of 1000 complete in 228.2 sec
#  [-----------------93%---------------   ] 937 of 1000 complete in 228.9 sec
#  [-----------------94%---------------   ] 940 of 1000 complete in 229.6 sec
#  [-----------------94%---------------   ] 942 of 1000 complete in 230.1 sec
#  [-----------------94%---------------   ] 944 of 1000 complete in 230.6 sec
#  [-----------------94%---------------   ] 946 of 1000 complete in 231.4 sec
#  [-----------------94%----------------  ] 948 of 1000 complete in 232.1 sec
#  [-----------------95%----------------  ] 951 of 1000 complete in 232.8 sec
#  [-----------------95%----------------  ] 954 of 1000 complete in 233.5 sec
#  [-----------------95%----------------  ] 957 of 1000 complete in 234.2 sec
#  [-----------------96%----------------  ] 960 of 1000 complete in 234.9 sec
#  [-----------------96%----------------  ] 963 of 1000 complete in 235.5 sec
#  [-----------------96%----------------  ] 966 of 1000 complete in 236.2 sec
#  [-----------------96%----------------  ] 968 of 1000 complete in 236.9 sec
#  [-----------------97%----------------  ] 970 of 1000 complete in 237.6 sec
#  [-----------------97%----------------  ] 973 of 1000 complete in 238.3 sec
#  [-----------------97%----------------- ] 976 of 1000 complete in 239.0 sec
#  [-----------------97%----------------- ] 979 of 1000 complete in 239.6 sec
#  [-----------------98%----------------- ] 982 of 1000 complete in 240.3 sec
#  [-----------------98%----------------- ] 985 of 1000 complete in 241.0 sec
#  [-----------------98%----------------- ] 988 of 1000 complete in 241.7 sec
#  [-----------------99%----------------- ] 991 of 1000 complete in 242.3 sec
#  [-----------------99%----------------- ] 994 of 1000 complete in 243.0 sec
#  [-----------------99%----------------- ] 997 of 1000 complete in 243.7 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 244.4 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 244.6 sec

# %%
Niters = len(M.xy_points.trace())

iters = np.linspace(0, Niters-1, 4).astype(np.int)
iters = np.logspace(0, np.log10(Niters-1), 4).astype(np.int)

for (subidx, iterN) in enumerate(iters):
    plt.subplot(2,2,subidx+1)
    plt.clf()
    plt.plot(M.xy_meas[:,0], M.xy_meas[:,1], linestyle='', marker='.', alpha=0.25)
    D = M.trace('xy_points')()[iterN]
    _x_nodes = np.array([M.trace('xy_nodes_%i'%i)()[iterN][0] for i in range(len(M.xy_nodes))])
    _y_nodes = np.array([M.trace('xy_nodes_%i'%i)()[iterN][1] for i in range(len(M.xy_nodes))])
    
    
    plt.plot(D[:,0], D[:,1], linestyle='', marker='.', color='r')
    plt.plot(_x_nodes, _y_nodes, linestyle='', marker='x', color='g', markersize=8, markeredgewidth=3)
    for (idx, (xt,yt)) in enumerate(zip(_x_nodes, _y_nodes)):
        plt.text(xt+.1,yt+.1,idx,size=15)

    plt.grid("on")
    plt.axis("equal")
    #break
    #plt.xlim([-20, 20])
    #plt.ylim([-20, 20])

# %%
M.log
# Out:
# -325009085.19003284

# %%
G = nx.Graph(M.adjMatrix.value)
G.degree()
# Out:
# {0: 1, 1: 3, 2: 2, 3: 2, 4: 2, 5: 3, 6: 2, 7: 2, 8: 3, 9: 2, 10: 1, 11: 3}

# %%
from sklearn.neighbors import KDTree

# %%
Ng = 200
x = np.linspace(-10000.,15000, Ng)
y = np.linspace(-10000.,10000, Ng)
#x = np.sort(np.random.rand(Ng) * 40. - 20.);
#y = np.sort(np.random.rand(Ng) * 40. - 20.);
xx, yy = np.meshgrid(x, y)

# %%
xy_grid = np.column_stack([xx.flatten(), yy.flatten()])

# %%
tree = KDTree(model.xy_meas)

# %%
tree_s = KDTree(model.xy_points.value)

# %%
fboo = tree.kernel_density(xy_grid, h=10, kernel='gaussian')

# %%
fboo_s = tree_s.kernel_density(xy_grid, h=20, kernel='gaussian')

# %%
fb = np.exp(np.log(fboo.reshape(Ng,Ng))*.1)
fb_s = np.exp(np.log(fboo_s.reshape(Ng, Ng))*.1)

# %%
#plt.contourf(x,y, fboo.reshape(Ng,Ng), alpha=.2)
#plt.plot(toy.xy_meas[:,0], toy.xy_meas[:,1], linestyle="", marker=".")


#plt.plot(model.xy_points.value[:,0], model.xy_points.value[:,1], linestyle="", color='k', marker=".")
#plt.plot(model.xy_meas[:,0], model.xy_meas[:,1], linestyle="", color='k', marker=".")

plt.contourf(x,y, fb, alpha=.4)
#plt.plot(xy_grid[:,0]-40, xy_grid[:,1],  linestyle='', color='k', marker=".", alpha=.5)

#plt.contourf(x,y, fb_s, alpha=.4, cmap=matplotlib.cm.hsv)


plt.axis("equal")
# Out:
# (-15000.0, 15000.0, -15000.0, 15000.0)

# %%
from sklearn.mixture import GMM

# %%
xGMM = GMM(300)

# %%
xGMM.fit(model.xy_meas)
# Out:
# GMM(covariance_type='diag', init_params='wmc', min_covar=0.001,
#   n_components=300, n_init=1, n_iter=100, params='wmc', random_state=None,
#   thresh=None, tol=0.001)

# %%
sc = xGMM.score(xy_grid)

# %%
xScore = np.exp(sc*.4).reshape(Ng, Ng)

# %%
plt.contourf(x, y, xScore, alpha=.9)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x7fb388ee1320>

# %%
model.seeP(M.Prows)
# Out:
# array([[ 0.015,  0.170,  0.102,  0.012,  0.357,  0.029,  0.184,  0.131],
#        [ 0.121,  0.005,  0.166,  0.169,  0.175,  0.173,  0.060,  0.131],
#        [ 0.077,  0.245,  0.000,  0.194,  0.055,  0.162,  0.076,  0.191],
#        [ 0.036,  0.014,  0.024,  0.168,  0.074,  0.121,  0.085,  0.478],
#        [ 0.144,  0.152,  0.048,  0.289,  0.003,  0.101,  0.071,  0.192],
#        [ 0.102,  0.162,  0.112,  0.135,  0.178,  0.000,  0.160,  0.151],
#        [ 0.072,  0.104,  0.137,  0.257,  0.041,  0.039,  0.000,  0.350],
#        [ 0.125,  0.028,  0.176,  0.423,  0.096,  0.019,  0.092,  0.041]])

# %%
M.logp#-191 with 3 points / -62 with 4 points / -22 with 5 points
# Out:
# -71706605.9696099

# %%
pymcPlt.plot(M.get_node('Sparsity'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-479b9a8fad4c> in <module>()
# ----> 1 pymcPlt.plot(M.get_node('x_node'))
#
# /usr/local/lib/python2.7/dist-packages/pymc/Matplot.pyc in wrapper(pymc_obj, *args, **kwargs)
#     375
#     376         # If others fail, assume that raw data is passed
# --> 377         f(pymc_obj, *args, **kwargs)
#     378
#     379     wrapper.__doc__ = f.__doc__
#
# TypeError: plot() takes at least 2 arguments (1 given)

# %%
so, sd
# Out:
# (1, 3)

# %%
f = M.frac[8:9]

# %%
x_o = np.array([p.value for p in M.x_nodes[so]])
x_d = np.array([p.value for p in M.x_nodes[sd]])
(x_d- x_o)*f + x_o
# Out:
# array([-6.788])

# %%
y_o = np.array([p.value for p in M.y_nodes[so]])
y_d = np.array([p.value for p in M.y_nodes[sd]])
f*(y_d- y_o) + y_o
# Out:
# array([ 1.356])

# %%
M.xy_points.value[8,0]
# Out:
# -6.7879401206498144

# %%
plt.plot(model.xy_meas[:,0], model.xy_meas[:,1], linestyle="", marker=".")

# %%
plt.plot(M.xy_points.value[:,0], M.xy_points.value[:,1], linestyle="", marker="o")

# %%
plen= len(M.trace('x_nodes_0')());
_x_nodes = np.array([M.trace('x_nodes_%i'%0)()[i] for i in range(plen)])
_y_nodes = np.array([M.trace('y_nodes_%i'%0)()[i] for i in range(plen)])
plt.plot(_x_nodes, _y_nodes, marker='.', linestyle="")
plt.grid("on")
#plt.xlim([-15, 15])
#plt.ylim([-5, 15])
