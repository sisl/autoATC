# %%
# %matplotlib inline
import pymc.Matplot as pymcPlt
import pymc
import matplotlib.pyplot as plt
import numpy as np

# %%
np.set_printoptions(formatter={'float': '{: 0.3f}'.format})

# %%
import toy

# %%
M = pymc.MCMC(toy)

# %%
M.sample(iter=1000,thin=10)#, burn=500, thin=50)
# Out:
#  [-                 4%                  ] 40 of 1000 complete in 0.5 sec
#  [---               8%                  ] 83 of 1000 complete in 1.0 sec
#  [----             12%                  ] 121 of 1000 complete in 1.5 sec
#  [------           16%                  ] 163 of 1000 complete in 2.0 sec
#  [-------          20%                  ] 207 of 1000 complete in 2.5 sec
#  [---------        25%                  ] 251 of 1000 complete in 3.0 sec
#  [-----------      29%                  ] 293 of 1000 complete in 3.5 sec
#  [------------     33%                  ] 334 of 1000 complete in 4.0 sec
#  [--------------   38%                  ] 380 of 1000 complete in 4.5 sec
#  [---------------- 42%                  ] 423 of 1000 complete in 5.1 sec
#  [-----------------46%                  ] 464 of 1000 complete in 5.6 sec
#  [-----------------50%                  ] 508 of 1000 complete in 6.1 sec
#  [-----------------55%                  ] 550 of 1000 complete in 6.6 sec
#  [-----------------59%--                ] 596 of 1000 complete in 7.1 sec
#  [-----------------63%----              ] 638 of 1000 complete in 7.6 sec
#  [-----------------68%------            ] 686 of 1000 complete in 8.1 sec
#  [-----------------72%-------           ] 729 of 1000 complete in 8.6 sec
#  [-----------------77%---------         ] 775 of 1000 complete in 9.1 sec
#  [-----------------82%-----------       ] 822 of 1000 complete in 9.6 sec
#  [-----------------86%------------      ] 867 of 1000 complete in 10.1 sec
#  [-----------------91%--------------    ] 912 of 1000 complete in 10.6 sec
#  [-----------------95%----------------  ] 958 of 1000 complete in 11.1 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 11.6 sec

# %%
Niters = len(M.xy_points.trace())

iters = np.linspace(0, Niters-1, 9).astype(np.int)
iters = np.logspace(0, np.log10(Niters-1), 9).astype(np.int)

for (subidx, iterN) in enumerate(iters):
    plt.subplot(3,3,subidx+1)
    plt.plot(M.x_meas, M.y_meas, linestyle='', marker='.')
    D = M.trace('xy_points')()[iterN]
    _x_nodes = np.array([M.trace('x_nodes_%i'%i)()[iterN] for i in range(len(M.x_nodes))])
    _y_nodes = np.array([M.trace('y_nodes_%i'%i)()[iterN] for i in range(len(M.x_nodes))])

    plt.plot(D[:,0], D[:,1], linestyle='', marker='.', color='r')
    plt.plot(_x_nodes, _y_nodes, linestyle='', marker='x', color='k', markersize=8, markeredgewidth=4)
    for (idx, (xt,yt)) in enumerate(zip(_x_nodes, _y_nodes)):
        plt.text(xt+.1,yt+.1,idx,size=15)

    plt.grid("on")
    plt.axis("equal")
    plt.xlim([-15, 15])
    plt.ylim([-5, 15])

# %%
pymcPlt.plot(M)
# Out:
# Plotting x_nodes_0
# Plotting
#  y_nodes_2
# Plotting
#  x_nodes_2
# Plotting
#  x_nodes_1
# Plotting
#  x_nodes_3
# Plotting
#  y_nodes_3
# Plotting
#  Dir_0_0
# Plotting
#  Dir_0_1
# Plotting
#  Dir_0_2
# Plotting
#  Dir_1_0
# Plotting
#  Dir_1_1
# Plotting
#  Dir_1_2
# Plotting
#  Dir_2_0
# Plotting
#  Dir_2_1
# Plotting
#  Dir_2_2
# Plotting
#  y_nodes_0
# Plotting
#  y_nodes_1
# Plotting
#  Dir_3_0
# Plotting
#  Dir_3_1
# Plotting
#  Dir_3_2

# %%
sd = []
for so in M.state_origin:
    s_d = [[s for i in range(v)] for (s,v) in enumerate(M.s_tp1[so])]
    s_d = np.array([s for ll in s_d for s in ll])
    sd.append(s_d)

# %%
cnt = np.zeros((4,4))
for so in M.state_origin:
    for d in sd[so]:
        cnt[so, d] += 1

# %%
cnt
# Out:
# array([[ 0.000,  0.000,  14.000,  11.000],
#        [ 6.000,  3.000,  0.000,  16.000],
#        [ 5.000,  0.000,  2.000,  18.000],
#        [ 7.000,  7.000,  11.000,  0.000]])

# %%
np.divide(cnt, np.reshape(np.repeat(np.sum(cnt, axis=1), 4), (4,4)))
# Out:
# array([[ 0.000,  0.000,  0.560,  0.440],
#        [ 0.240,  0.120,  0.000,  0.640],
#        [ 0.200,  0.000,  0.080,  0.720],
#        [ 0.280,  0.280,  0.440,  0.000]])

# %%
toy.seeP(M.Prows)
# Out:
# array([[ 0.000,  0.243,  0.388,  0.368],
#        [ 0.371,  0.022,  0.239,  0.368],
#        [ 0.228,  0.197,  0.015,  0.561],
#        [ 0.401,  0.320,  0.279,  0.000]])

# %%
so, sd
# Out:
# (1, 3)

# %%
f = M.frac[8:9]

# %%
x_o = np.array([p.value for p in M.x_nodes[so]])
x_d = np.array([p.value for p in M.x_nodes[sd]])
(x_d- x_o)*f + x_o
# Out:
# array([-6.788])

# %%
y_o = np.array([p.value for p in M.y_nodes[so]])
y_d = np.array([p.value for p in M.y_nodes[sd]])
f*(y_d- y_o) + y_o
# Out:
# array([ 1.356])

# %%
M.xy_points.value[8,0]
# Out:
# -6.7879401206498144

# %%
plt.plot(M.xy_points.value[:,0], M.xy_points.value[:,1], linestyle="", marker="o")

# %%
iterP = np.row_stack([M.trace('Dir_%i'%i)()[iterN] for i in range(M.Nnodes)])
iterP = np.column_stack([iterP, 1-np.sum(iterP,axis=1)])
iterP = (iterP + iterP.transpose())*0.5
print(iterP)
# Out:
# [[ 0.000  0.236  0.356  0.277]
#  [ 0.236  0.003  0.182  0.468]
#  [ 0.356  0.182  0.000  0.479]
#  [ 0.277  0.468  0.479  0.004]]

# %%
plen= len(M.trace('x_nodes_0')());
_x_nodes = np.array([M.trace('x_nodes_%i'%2)()[i] for i in range(plen)])
_y_nodes = np.array([M.trace('y_nodes_%i'%2)()[i] for i in range(plen)])
plt.plot(_x_nodes, _y_nodes, marker='.', linestyle="")
plt.grid("on")
#plt.xlim([-15, 15])
#plt.ylim([-5, 15])

# %%
pymcPlt.plot(M.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c98682d05d0e> in <module>()
# ----> 1 pymcPlt.plot(M.frac)
#
# /usr/local/lib/python2.7/dist-packages/pymc/Matplot.pyc in wrapper(pymc_obj, *args, **kwargs)
#     375
#     376         # If others fail, assume that raw data is passed
# --> 377         f(pymc_obj, *args, **kwargs)
#     378
#     379     wrapper.__doc__ = f.__doc__
#
# TypeError: plot() takes at least 2 arguments (1 given)

# %%
toy.sample(xy_sample); 
testP = (seeP(Prows) + seeP(Prows).transpose())*0.5
np.min(testP + np.eye(4))
# Out:
# 0.041665854271272965
