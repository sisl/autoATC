# %%
# %matplotlib inline
import pymc.Matplot as pymcPlt
import pymc
import matplotlib.pyplot as plt
import numpy as np

# %%
np.set_printoptions(formatter={'float': '{: 0.3f}'.format})

# %%
import toy

# %%
M = pymc.MCMC(toy)

# %%
M.sample(iter=1000,thin=10)#, burn=500, thin=50)
# Out:
#  [                  1%                  ] 14 of 1000 complete in 0.5 sec
#  [                  2%                  ] 25 of 1000 complete in 1.0 sec
#  [-                 3%                  ] 37 of 1000 complete in 1.6 sec
#  [-                 5%                  ] 51 of 1000 complete in 2.1 sec
#  [--                6%                  ] 63 of 1000 complete in 2.6 sec
#  [--                7%                  ] 76 of 1000 complete in 3.1 sec
#  [---               9%                  ] 90 of 1000 complete in 3.6 sec
#  [---              10%                  ] 101 of 1000 complete in 4.2 sec
#  [----             11%                  ] 113 of 1000 complete in 4.7 sec
#  [----             12%                  ] 125 of 1000 complete in 5.2 sec
#  [-----            13%                  ] 137 of 1000 complete in 5.7 sec
#  [-----            14%                  ] 147 of 1000 complete in 6.2 sec
#  [------           15%                  ] 159 of 1000 complete in 6.7 sec
#  [------           17%                  ] 171 of 1000 complete in 7.2 sec
#  [------           18%                  ] 184 of 1000 complete in 7.7 sec
#  [-------          19%                  ] 199 of 1000 complete in 8.3 sec
#  [--------         21%                  ] 213 of 1000 complete in 8.8 sec
#  [--------         22%                  ] 227 of 1000 complete in 9.3 sec
#  [---------        24%                  ] 241 of 1000 complete in 9.8 sec
#  [---------        25%                  ] 254 of 1000 complete in 10.3 sec
#  [----------       26%                  ] 267 of 1000 complete in 10.8 sec
#  [----------       28%                  ] 282 of 1000 complete in 11.3 sec
#  [-----------      29%                  ] 297 of 1000 complete in 11.9 sec
#  [-----------      31%                  ] 312 of 1000 complete in 12.4 sec
#  [------------     32%                  ] 327 of 1000 complete in 12.9 sec
#  [------------     34%                  ] 340 of 1000 complete in 13.4 sec
#  [-------------    35%                  ] 354 of 1000 complete in 14.0 sec
#  [-------------    36%                  ] 368 of 1000 complete in 14.5 sec
#  [--------------   38%                  ] 383 of 1000 complete in 15.0 sec
#  [---------------  39%                  ] 397 of 1000 complete in 15.5 sec
#  [---------------  40%                  ] 406 of 1000 complete in 16.0 sec
#  [---------------  41%                  ] 415 of 1000 complete in 16.6 sec
#  [---------------- 42%                  ] 427 of 1000 complete in 17.1 sec
#  [---------------- 44%                  ] 442 of 1000 complete in 17.6 sec
#  [-----------------45%                  ] 456 of 1000 complete in 18.1 sec
#  [-----------------47%                  ] 470 of 1000 complete in 18.6 sec
#  [-----------------48%                  ] 484 of 1000 complete in 19.2 sec
#  [-----------------49%                  ] 499 of 1000 complete in 19.7 sec
#  [-----------------51%                  ] 514 of 1000 complete in 20.2 sec
#  [-----------------52%                  ] 528 of 1000 complete in 20.7 sec
#  [-----------------54%                  ] 542 of 1000 complete in 21.3 sec
#  [-----------------55%-                 ] 555 of 1000 complete in 21.8 sec
#  [-----------------56%-                 ] 569 of 1000 complete in 22.3 sec
#  [-----------------58%--                ] 583 of 1000 complete in 22.8 sec
#  [-----------------59%--                ] 598 of 1000 complete in 23.3 sec
#  [-----------------61%---               ] 611 of 1000 complete in 23.8 sec
#  [-----------------61%---               ] 618 of 1000 complete in 24.3 sec
#  [-----------------63%---               ] 630 of 1000 complete in 24.8 sec
#  [-----------------64%----              ] 644 of 1000 complete in 25.4 sec
#  [-----------------65%-----             ] 659 of 1000 complete in 25.9 sec
#  [-----------------67%-----             ] 672 of 1000 complete in 26.4 sec
#  [-----------------68%------            ] 686 of 1000 complete in 26.9 sec
#  [-----------------70%------            ] 700 of 1000 complete in 27.4 sec
#  [-----------------71%-------           ] 714 of 1000 complete in 27.9 sec
#  [-----------------72%-------           ] 728 of 1000 complete in 28.5 sec
#  [-----------------74%--------          ] 742 of 1000 complete in 29.0 sec
#  [-----------------75%--------          ] 757 of 1000 complete in 29.5 sec
#  [-----------------77%---------         ] 771 of 1000 complete in 30.0 sec
#  [-----------------78%---------         ] 786 of 1000 complete in 30.5 sec
#  [-----------------79%----------        ] 799 of 1000 complete in 31.1 sec
#  [-----------------81%----------        ] 814 of 1000 complete in 31.6 sec
#  [-----------------82%-----------       ] 822 of 1000 complete in 32.1 sec
#  [-----------------83%-----------       ] 836 of 1000 complete in 32.6 sec
#  [-----------------85%------------      ] 850 of 1000 complete in 33.2 sec
#  [-----------------86%------------      ] 865 of 1000 complete in 33.7 sec
#  [-----------------87%-------------     ] 878 of 1000 complete in 34.2 sec
#  [-----------------89%-------------     ] 892 of 1000 complete in 34.7 sec
#  [-----------------90%--------------    ] 904 of 1000 complete in 35.2 sec
#  [-----------------91%--------------    ] 917 of 1000 complete in 35.7 sec
#  [-----------------93%---------------   ] 931 of 1000 complete in 36.3 sec
#  [-----------------94%---------------   ] 944 of 1000 complete in 36.8 sec
#  [-----------------95%----------------  ] 959 of 1000 complete in 37.3 sec
#  [-----------------97%----------------  ] 973 of 1000 complete in 37.8 sec
#  [-----------------98%----------------- ] 988 of 1000 complete in 38.3 sec
#  [-----------------100%-----------------] 1000 of 1000 complete in 38.8 sec

# %%
Niters = len(M.xy_points.trace())

iters = np.linspace(0, Niters-1, 9).astype(np.int)
iters = np.logspace(0, np.log10(Niters-1), 9).astype(np.int)

for (subidx, iterN) in enumerate(iters):
    plt.subplot(3,3,subidx+1)
    plt.plot(M.x_meas, M.y_meas, linestyle='', marker='.')
    D = M.trace('xy_points')()[iterN]
    _x_nodes = np.array([M.trace('x_nodes_%i'%i)()[iterN] for i in range(len(M.x_nodes))])
    _y_nodes = np.array([M.trace('y_nodes_%i'%i)()[iterN] for i in range(len(M.x_nodes))])

    plt.plot(D[:,0], D[:,1], linestyle='', marker='.', color='r')
    plt.plot(_x_nodes, _y_nodes, linestyle='', marker='x', color='k', markersize=8, markeredgewidth=3)
    for (idx, (xt,yt)) in enumerate(zip(_x_nodes, _y_nodes)):
        plt.text(xt+.1,yt+.1,idx,size=15)

    plt.grid("on")
    #plt.axis("equal")
    plt.xlim([-20, 20])
    plt.ylim([-20, 20])

# %%
toy.seeP(M.Prows)
# Out:
# array([[ 0.000,  0.243,  0.358,  0.256,  0.142],
#        [ 0.163,  0.000,  0.449,  0.274,  0.114],
#        [ 0.186,  0.336,  0.008,  0.212,  0.258],
#        [ 0.272,  0.309,  0.383,  0.000,  0.036],
#        [ 0.354,  0.183,  0.211,  0.251,  0.000]])

# %%
toy.dataScore.get_logp() #-191 with 3 points / -62 with 4 points / -22 with 5 points
# Out:
# -46.97582392477259

# %%
pymcPlt.plot(M)
# Out:
# Plotting x_nodes_3
# Plotting
#  x_nodes_1
# Plotting
#  x_nodes_2
# Plotting
#  y_nodes_2
# Plotting
#  Dir_2_0
# Plotting
#  Dir_2_1
# Plotting
#  Dir_2_2
# Plotting
#  Dir_2_3
# Plotting
#  y_nodes_3
# Plotting
#  Dir_4_0
# Plotting
#  Dir_4_1
# Plotting
#  Dir_4_2
# Plotting
#  Dir_4_3
# Plotting
#  y_nodes_4
# Plotting
#  y_nodes_0
# Plotting
#  Dir_0_0
# Plotting
#  Dir_0_1
# Plotting
#  Dir_0_2
# Plotting
#  Dir_0_3
# Plotting
#  x_nodes_4
# Plotting
#  Dir_1_0
# Plotting
#  Dir_1_1
# Plotting
#  Dir_1_2
# Plotting
#  Dir_1_3
# Plotting
#  y_nodes_1
# Plotting
#  x_nodes_0
# Plotting
#  Dir_3_0
# Plotting
#  Dir_3_1
# Plotting
#  Dir_3_2
# Plotting
#  Dir_3_3

# %%
so, sd
# Out:
# (1, 3)

# %%
f = M.frac[8:9]

# %%
x_o = np.array([p.value for p in M.x_nodes[so]])
x_d = np.array([p.value for p in M.x_nodes[sd]])
(x_d- x_o)*f + x_o
# Out:
# array([-6.788])

# %%
y_o = np.array([p.value for p in M.y_nodes[so]])
y_d = np.array([p.value for p in M.y_nodes[sd]])
f*(y_d- y_o) + y_o
# Out:
# array([ 1.356])

# %%
M.xy_points.value[8,0]
# Out:
# -6.7879401206498144

# %%
plt.plot(M.xy_points.value[:,0], M.xy_points.value[:,1], linestyle="", marker="o")

# %%
iterP = np.row_stack([M.trace('Dir_%i'%i)()[iterN] for i in range(M.Nnodes)])
iterP = np.column_stack([iterP, 1-np.sum(iterP,axis=1)])
iterP = (iterP + iterP.transpose())*0.5
print(iterP)
# Out:
# [[ 0.000  0.236  0.356  0.277]
#  [ 0.236  0.003  0.182  0.468]
#  [ 0.356  0.182  0.000  0.479]
#  [ 0.277  0.468  0.479  0.004]]

# %%
plen= len(M.trace('x_nodes_0')());
_x_nodes = np.array([M.trace('x_nodes_%i'%4)()[i] for i in range(plen)])
_y_nodes = np.array([M.trace('y_nodes_%i'%4)()[i] for i in range(plen)])
plt.plot(_x_nodes, _y_nodes, marker='.', linestyle="")
plt.grid("on")
#plt.xlim([-15, 15])
#plt.ylim([-5, 15])

# %%
plt.plot(toy.x_meas, toy.y_meas, linestyle='', marker='.')
plt.plot(toy.x_true, toy.y_true, linestyle='', marker='x',color='k',markersize=10,markeredgewidth=3)
for (idx, (xt,yt)) in enumerate(zip(toy.x_true, toy.y_true)):
        plt.text(xt+.1,yt+.1,idx,size=15)
