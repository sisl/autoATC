# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
legalActions = validCompactActions
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
P0 = spzeros(Float32, g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])
        end
    end
end
M0 = speye(Float32, g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./(teaTime[s]/60)
end

Isp = speye(Float32, g_nNodes);
Qt_list = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
 #g_nScomp 
Vshort = zeros(Float32,g_nSlong);

# %%
g_nScomp, g_nSlong / g_nScomp,
# Out:
# (3321960,22.518393057110863)

# %%
g_nSlong
# Out:
# 74805201

# %%
using CPUTime

using ProfileView
Profile.init(1000000*10, 0.001)

# %%
Aopt = @profile gaussSeidel!(Qt_list, Vshort, 0.1f0; maxIters = 1, maxTime = 5.*30.);
unique(Aopt)
#1 phase takes  .5s / iteration 
#2 phase takes   3s / iteration
#3 phase takes  ~12s / iteration 
#4 phase takes ~20s / iteration
# Out:
# Stopping after 1
#  iterations (maxVchange = 6843.70)
# elapsed time: 19.365257821 seconds (15816 bytes allocated)
# 13-element Array{Array{Int64,1},1}:
#  [0,0]
#  [4,1]
#  [4,3]
#  [4,2]
#  [3,1]
#  [3,2]
#  [3,3]
#  [2,1]
#  [2,2]
#  [2,3]
#  [1,1]
#  [1,2]
#  [1,3]

# %%
ProfileView.view()
# Out:
# ProfileData(7920x15 Array{RGB{Float64},2}:
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0),[0x00007ff560175792=>LineInfo("NcolNtaxi","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",285,false,140691855857554),0x00007ff5601762f5=>LineInfo("setindex!","sparse/sparsematrix.jl",33,false,140691855860469),0x00007ff560177114=>LineInfo("Ppq_v!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",51,false,140691855864084),0x00007ff56c76fa51=>LineInfo("???","???",140692063451729,true,140692063451729),0x00007ff560176d9a=>LineInfo("pqlqp","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",41,false,140691855863194),0x00007ff560176d9d=>LineInfo("pqlqp","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",41,false,140691855863197),0x00007ff56017386d=>LineInfo("gaussSeidel!","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",350,false,140691855849581),0x00007ff56017584c=>LineInfo("_mapreduce","reduce.jl",158,false,140691855857740),0x00007ff560173b48=>LineInfo("gaussSeidel!","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",373,false,140691855850312),0x00007ff56d7da0d0=>LineInfo("???","???",140692080664784,true,140692080664784),0x00007ff569d2ffde=>LineInfo("insert!","array.jl",548,false,140692019150814),0x00007ff560176b29=>LineInfo("Cbt!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",164,false,140691855862569),0x00007ff56a2baeb6=>LineInfo("StepRange","./range.jl",0,false,140692024962742),0x00007ff569cbb0f6=>LineInfo("power_by_squaring","intfuncs.jl",63,false,140692018671862),0x00007ff560174f7c=>LineInfo("X2LIDX","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",109,false,140691855855484),0x00007ff56c763f01=>LineInfo("jl_array_grow_end","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140692063403777),0x00007ff5601759c6=>LineInfo("getindex","sparse/sparsematrix.jl",757,false,140691855858118),0x00007ff56017693d=>LineInfo("Cbt!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",164,false,140691855862077),0x00007ff560175af2=>LineInfo("getindex","sparse/sparsematrix.jl",762,false,140691855858418),0x00007ff560174fa6=>LineInfo("X2LIDX","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",111,false,140691855855526),0x00007fff62dfef06=>LineInfo("__vdso_gettimeofday","",-1,true,140734852230918),0x00007ff56d7dd860=>LineInfo("???","???",140692080679008,true,140692080679008),0x00007ff56017589c=>LineInfo("_mapreduce","reduce.jl",164,false,140691855857820),0x00007ff569d2ffd0=>LineInfo("insert!","array.jl",547,false,140692019150800),0x00007ff560176315=>LineInfo("setindex!","sparse/sparsematrix.jl",1264,false,140691855860501),0x00007ff56c763f1b=>LineInfo("jl_array_grow_end","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140692063403803),0x00007ff56c7713e5=>LineInfo("allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140692063458277),0x00007ff560176f96=>LineInfo("sparseVectorPlusEq!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",126,false,140691855863702),0x00007ff56017704d=>LineInfo("Ppq_v!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",46,false,140691855863885),0x00007ff5601774eb=>LineInfo("validCompActions!","/home/zouhair/Dropbox/Research/autoATC/pattern.jl",401,false,140691855865067),0x00007ff569d302a0=>LineInfo("insert!","array.jl",547,false,140692019151520),0x00007ff560173b14=>LineInfo("gaussSeidel!","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",372,false,140691855850260),0x00007ff569d302ae=>LineInfo("insert!","array.jl",548,false,140692019151534),0x00007ff569cbb13b=>LineInfo("power_by_squaring","intfuncs.jl",54,false,140692018671931),0x00007ff560176ba5=>LineInfo("Cbt!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",164,false,140691855862693),0x00007ff569d2e194=>LineInfo("pointer","pointer.jl",29,false,140692019143060),0x00007ff5601737d7=>LineInfo("gaussSeidel!","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",343,false,140691855849431),0x00007ff56c76a40c=>LineInfo("???","???",140692063429644,true,140692063429644),0x00007ff56c76f947=>LineInfo("???","???",140692063451463, ...
#  TagData(0x00007ff569cf617f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  ⋮                              ⋱
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007ff569cf617f,0)     TagData(0x0000000000000000,-1),12)

# %%
ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# filename = "CTMDPpolicy_a_" * string(α) * "_b_" * string(β_cost) * ".jld"
# save(filename, "Aopt", Aopt, "Vstar", Vshort, "α", α, "β_cost", β_cost);
# filename

# %%
s = [:LD2,:RD2, :T, :T]; s2 = [:F1,:U1, :LX1, :T];#,:T,:T]#,:LArr];

# %%
ctmdpPolicy(s), ctmdpPolicy(s2)
# Out:
# ((1,:ϕ1_LD3),(1,:ϕ1_GO))

# %%
P[3][s2x(s[1]),:]
# Out:
# 1x27 sparse matrix with 1 Float64 entries:
# 	[1 , 22]  =  1.0

# %%
q1 = Qi(Qlist[1], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q3 = Qi(Qlist[3], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q1, q3
# Out:
# (
# 531441x1 sparse matrix with 7 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[220159,      1]  =  0.25
# 	[416989,      1]  =  0.25,
#
# 531441x1 sparse matrix with 6 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[416989,      1]  =  0.5)

# %%
[(LIDX2S(lidx),q1[lidx]) for lidx in q1.rowval[q1.colptr[1]:(q1.colptr[2]-1)]]
# Out:
# 7-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RB1,:LD2,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.24999999500000009)

# %%
[(LIDX2S(lidx),q3[lidx]) for lidx in q3.rowval[q3.colptr[1]:(q3.colptr[2]-1)]]
# Out:
# 6-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.49999999000000017)

# %%
s = [:RD2,:LD2]
for ac in legalActions(s)
    a = compAct2extAct(ac,s)
    X =  sort(S2X(s))
    @printf("a = %s (%s), Q(V,a)=%.2f \n",a, ac, QVeval(X,ac, Qlist,Vshort,1e6))
    for sp in getNextPerms(s)
        tp = Transition(s, a, sp)
        for spp in getNextPerms(sp)
            @printf("%s->%s->%s, p = %.2f, R = %.2f, V=%.2f\n",
            s, sp, spp,
            tp * Transition(sp, g_noaction, spp), Reward(spp, g_nullAct,0.1),
            Vshort[S2CIDX(spp)]
            )
        end
    end
end
# Out:
# key not found: [6,11]
# while loading In[21], in expression starting on line 2
#
#  in X2CIDX at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:75
#  in QVeval at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:232
#  in anonymous at no file:5

# %%
legalActions(s)
# Out:
# 5x1 Array{Array{Int64,1},2}:
#  [0,0]
#  [1,1]
#  [1,2]
#  [2,1]
#  [2,2]

# %%
#popo = [CIDX2S(cidx) => policy_S2a(CIDX2S(cidx),Aopt) for cidx in find(x-> x != g_noaction, Aopt)]

# %%
#using ProfileView
#@profile Aopt = gaussSeidel!(Qlist, Vshort,1.2,1)# at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:268
#ProfileView.view()

# %%
# for cidx in 1:g_nScomp
#     S = CIDX2S(cidx) 
#     a = ctmdpPolicy(S)
#     if a != g_noaction
#         @printf("%s -> %s\n",S, a) 
#     end
# end

# %%
a = 1;
@which a += 1
# Out:
# expression is not a function call, or is too complex for @which to analyze; break it down to simpler parts if possible
# while loading In[10], in expression starting on line 2
#
#  in error at error.jl:21
