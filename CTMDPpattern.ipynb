# %%
using CPUTime

# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
legalActions = validCompactActions
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
P0 = spzeros(Float32, g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])
        end
    end
end
M0 = speye(Float32, g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./(teaTime[s]/60)
end

Isp = speye(Float32, g_nNodes);
Qt_list = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
 #g_nScomp 
Vshort = zeros(Float32,g_nSlong);

# %%
g_nScomp, g_nSlong / g_nScomp,
# Out:
# (1150626,22.085091941256326)

# %%
@printf("%.1e\n",g_nSlong)
# Out:
# 2.
# 5e+07

# %%
data_n1 = load("CTMDPpolicy_n_1_a_1.0_b_0.jld");

# %%
@time @CPUtime liftUpPolicy!(Qt_list, Vshort, 0.1f0, data_n1["Aopt"]; maxTime = 60. )
# Out:
# At iteration #5
# : maxVchange = 187.68 , t = 14.50 sec
# At iteration #
# 10: maxVchange = 105.63 , t = 29.12 sec
# Stopping after
# 11 iterations (maxVchange = 92.25)
# elapsed time: 32.042552051 seconds (48664 bytes allocated)
# elapsed CPU time: 47.278436 seconds
# elapsed time: 47.572581866 seconds (2225394968 bytes allocated, 20.68% gc time)

# %%
using PyPlot;

# %%
idx = (1:500) + 1e4
PyPlot.plot(Vshort[idx]-Vtest[idx])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fbc91e4b310>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fbc91b11d10>

# %%
# using ProfileView
# Profile.init(1000000*10, 0.001)

# %%
Aopt = @CPUtime gaussSeidel!(Qt_list, Vshort, 0.1f0) #; maxIters = 1, maxTime = 5.*30.);
unique(Aopt)
#1 phase takes  0.2s / iteration: 45 iterations, 10s ~500K states
#2 phase takes  1.5s / iteration: 51 iterations, 70s  ~5M states
#3 phase takes  ~5s  / iteration: 61 iterations, 340s ~25M states
#4 phase takes ~20s  / iteration: 83 iterations, 1200s ~75M states
# Out:
# At iteration #5
# : maxVchange = 636.76 , t = 23.64 sec
# At iteration #
# 10: maxVchange = 307.32 , t = 47.55 sec
# At iteration #
# 15: maxVchange = 192.13 , t = 71.45 sec
# At iteration #
# 20: maxVchange = 117.16 , t = 95.31 sec
# At iteration #
# 25: maxVchange = 73.14 , t = 119.04 sec
# At iteration #
# 30: maxVchange = 28.52 , t = 145.49 sec
# At iteration #
# 35: maxVchange = 11.71 , t = 176.35 sec
# At iteration #
# 40: maxVchange = 4.96 , t = 203.35 sec
# At iteration #
# 45: maxVchange = 2.39 , t = 230.65 sec
# At iteration #
# 50: maxVchange = 1.69 , t = 257.82 sec
# At iteration #
# 55: maxVchange = 1.23 , t = 282.73 sec
# Stopping after
# 58 iterations (maxVchange = 0.94)
# elapsed time: 297.362331262 seconds (259376 bytes allocated)
# elapsed CPU time: 296.919226 seconds
# 13-element Array{Array{Int64,1},1}:
#  [0,0]
#  [4,1]
#  [4,3]
#  [4,2]
#  [3,1]
#  [3,2]
#  [3,3]
#  [2,1]
#  [2,2]
#  [2,3]
#  [1,1]
#  [1,2]
#  [1,3]

# %%
PyPlot.plot(Vshort[1:5000])
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fbce1a73650>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fbcbd5ce210>

# %%
# ProfileView.view()

# %%
ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# β_cost = 0
# filename = "CTMDPpolicy_n_" * string(nPhases) * "_a_" * string(α) * "_b_" * string(β_cost) * ".jld"
# save(filename, "Aopt", Aopt, "Vstar", Vshort, "α", α, "β_cost", β_cost);
# filename

# %%
s = [:LB1, :RD2, :RX1, :LX1]; s2 = [:F1, :U1, :LX1, :T];#,:T,:T]#,:LArr];

# %%
ctmdpPolicy(s), ctmdpPolicy(s2)
# Out:
# ((2,:ϕ1_RD3),(2,:ϕ1_RX1))

# %%
# for cidx in 1:g_nScomp
#     S = CIDX2S(cidx) 
#     a = ctmdpPolicy(S)
#     if a != g_noaction
#         @printf("%s -> %s\n",S, a) 
#     end
# end

# %%
g_Scomp[300 + (1:10)]
# Out:
# 10-element Array{Array{Symbol,1},1}:
#  [:T,:T,:LX1,:ϕ2_T]
#  [:T,:T,:LX1,:ϕ1_U2]
#  [:T,:T,:LX1,:ϕ2_RB2]
#  [:T,:T,:LX1,:ϕ3_RD2]
#  [:T,:T,:LX1,:ϕ2_RB1]
#  [:T,:T,:LX1,:ϕ3_LX2]
#  [:T,:T,:LX1,:ϕ2_LD2]
#  [:T,:T,:LX1,:ϕ3_F1]
#  [:T,:T,:LX1,:ϕ3_LB2]
#  [:T,:T,:LX1,:ϕ2_LD1]

# %%
g_allstates[1:28]
# Out:
# 28-element Array{Symbol,1}:
#  :T
#  :R
#  :U1
#  :LX1
#  :LD1
#  :LD2
#  :LB1
#  :F1
#  :RX1
#  :RD1
#  :RD2
#  :RB1
#  :GO
#  ⋮
#  :LD3
#  :LB2
#  :F0
#  :RX2
#  :RD0
#  :RD3
#  :RB2
#  :LDep
#  :LArr
#  :RDep
#  :RArr
#  :ϕ2_T
