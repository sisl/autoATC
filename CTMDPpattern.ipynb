# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
β_cost = 0.0;
legalActions = validCompactActions
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
P0 = spzeros(g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])
        end
    end
end
M0 = speye(g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./(teaTime[s]/60)
end

Isp = spdiagm(ones(g_nNodes));
Qt_list = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
 #g_nScomp 
Vshort = zeros(Float32,g_nSlong);

# %%
sizeof(Vshort)/1e6
# Out:
# 299.220804

# %%
g_nScomp, g_nSlong / g_nScomp,
# Out:
# (3321960,22.518393057110863)

# %%
using CPUTime

using ProfileView
Profile.init(1000000*10, 0.001)

# %%
@profile Aopt = gaussSeidel!(Qt_list, Vshort, 0.1; maxIters = 2, maxTime = 200.);
unique(Aopt)
#1 phase takes  .5s / iteration 
#2 phase takes   3s / iteration
#3 phase takes  ~12s / iteration 
#4 phase takes ~50s / iteration
# Out:
# Stopping after 2
#  iterations (maxVchange = 13513.42)
# elapsed time: 102.60856608 seconds (5438104668 bytes allocated, 56.75% gc time)
# Aopt not defined
# while loading In[8], in expression starting on line 2

# %%
ProfileView.view()
# Out:
# WARNING: The profile data buffer is full; profiling probably terminated
# before your program finished. To profile for longer runs, call Profile.init
# with a larger buffer and/or larger delay.
# ProfileData(8085x14 Array{RGB{Float64},2}:
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0),[0x00007f3d24b5bef7=>LineInfo("setindex!","sparse/sparsematrix.jl",1258,false,139900585623287),0x00007f3d1c0fb695=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",219,false,139900440524437),0x00007f3d1c0fc06e=>LineInfo("AaKronebSum!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",116,false,139900440526958),0x00007f3d1c0fcae8=>LineInfo("sparseVectorPlusEq!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",126,false,139900440529640),0x00007f3d1c0fc5a0=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",155,false,139900440528288),0x00007f3d27541fc6=>LineInfo("jl_apply_generic","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629557190),0x00007f3d1c0fc609=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",160,false,139900440528393),0x00007f3d2759c4f4=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629927156),0x00007f3d1c0fc5be=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",156,false,139900440528318),0x00007f3d2758ef0d=>LineInfo("jl_array_grow_end","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629872397),0x00007f3d24b5ca21=>LineInfo("insert!","array.jl",549,false,139900585626145),0x00007f3d1c0fc620=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",160,false,139900440528416),0x00007f3d2758ef01=>LineInfo("jl_array_grow_end","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629872385),0x00007f3d2753e983=>LineInfo("???","???",139900629543299,true,139900629543299),0x00007f3d1c0fb7aa=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",228,false,139900440524714),0x00007f3d1c0fa10b=>LineInfo("gaussSeidel!","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",358,false,139900440518923),0x00007f3d1c0fb440=>LineInfo("X2LIDX","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",105,false,139900440523840),0x00007f3d2759aaf3=>LineInfo("???","???",139900629920499,true,139900629920499),0x00007f3d24b5c7a0=>LineInfo("_growat!","array.jl",390,false,139900585625504),0x00007f3d1c0fcc8c=>LineInfo("Ppq_v!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",51,false,139900440530060),0x00007f3d1c0fc2d4=>LineInfo("eaKronv!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",89,false,139900440527572),0x00007f3d1c0fd30f=>LineInfo("_mapreduce","reduce.jl",163,false,139900440531727),0x00007f3d24b5c121=>LineInfo("setindex!","sparse/sparsematrix.jl",1254,false,139900585623841),0x00007f3d1c0fcae5=>LineInfo("sparseVectorPlusEq!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",126,false,139900440529637),0x00007f3d2759b9fd=>LineInfo("jl_gc_collect","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629924349),0x00007f3d24b5bf7a=>LineInfo("setindex!","sparse/sparsematrix.jl",1262,false,139900585623418),0x00007f3d1c0fc0f9=>LineInfo("AaKronebSum!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",118,false,139900440527097),0x00007f3d24b1e779=>LineInfo("eventloop","/home/zouhair/.julia/v0.3/IJulia/src/IJulia.jl",123,false,139900585371513),0x00007f3d1c0fc167=>LineInfo("AaKronebSum!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",118,false,139900440527207),0x00007f3d2759b9e0=>LineInfo("jl_gc_collect","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,139900629924320),0x00007f3d2759aaa6=>LineInfo("???","???",139900629920422,true,139900629920422),0x00007f3d2759a947=>LineInfo("???","???",139900629920071,true,139900629920071),0x00007f3d25239c25=>LineInfo("push!","./array.jl",461,false,139900592823333),0x00007f3d1c0f985f=>LineInfo("julia_gaussSeidel!_21084","",-1,true,139900440516703),0x00007f3d2759acd3=>LineInfo("???","???",139900629920979,true,139900629920979),0x00007f3d24b5c7a5=>LineInfo("_growat!","array.jl",390,false,139900585625509),0x00007f3d1c0fcd97=>LineInfo("pqlqp","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",41,false, ...
#  TagData(0x00007f3d24b2117f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  ⋮                              ⋱
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f3d24b2117f,0)     TagData(0x0000000000000000,-1),12)

# %%
ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# filename = "CTMDPpolicy_a_" * string(α) * "_b_" * string(β_cost) * ".jld"
# save(filename, "Aopt", Aopt, "Vstar", Vshort, "α", α, "β_cost", β_cost);
# filename

# %%
s = [:LD2,:RD2, :T, :T]; s2 = [:F1,:U1, :LX1, :T];#,:T,:T]#,:LArr];

# %%
ctmdpPolicy(s), ctmdpPolicy(s2)
# Out:
# ((2,:RD3),(2,:U2))

# %%
P[3][s2x(s[1]),:]
# Out:
# 1x27 sparse matrix with 1 Float64 entries:
# 	[1 , 22]  =  1.0

# %%
q1 = Qi(Qlist[1], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q3 = Qi(Qlist[3], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q1, q3
# Out:
# (
# 531441x1 sparse matrix with 7 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[220159,      1]  =  0.25
# 	[416989,      1]  =  0.25,
#
# 531441x1 sparse matrix with 6 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[416989,      1]  =  0.5)

# %%
[(LIDX2S(lidx),q1[lidx]) for lidx in q1.rowval[q1.colptr[1]:(q1.colptr[2]-1)]]
# Out:
# 7-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RB1,:LD2,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.24999999500000009)

# %%
[(LIDX2S(lidx),q3[lidx]) for lidx in q3.rowval[q3.colptr[1]:(q3.colptr[2]-1)]]
# Out:
# 6-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.49999999000000017)

# %%
s = [:RD2,:LD2]
for ac in legalActions(s)
    a = compAct2extAct(ac,s)
    X =  sort(S2X(s))
    @printf("a = %s (%s), Q(V,a)=%.2f \n",a, ac, QVeval(X,ac, Qlist,Vshort,1e6))
    for sp in getNextPerms(s)
        tp = Transition(s, a, sp)
        for spp in getNextPerms(sp)
            @printf("%s->%s->%s, p = %.2f, R = %.2f, V=%.2f\n",
            s, sp, spp,
            tp * Transition(sp, g_noaction, spp), Reward(spp, g_nullAct,0.1),
            Vshort[S2CIDX(spp)]
            )
        end
    end
end
# Out:
# key not found: [6,11]
# while loading In[21], in expression starting on line 2
#
#  in X2CIDX at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:75
#  in QVeval at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:232
#  in anonymous at no file:5

# %%
legalActions(s)
# Out:
# 5x1 Array{Array{Int64,1},2}:
#  [0,0]
#  [1,1]
#  [1,2]
#  [2,1]
#  [2,2]

# %%
#popo = [CIDX2S(cidx) => policy_S2a(CIDX2S(cidx),Aopt) for cidx in find(x-> x != g_noaction, Aopt)]

# %%
#using ProfileView
#@profile Aopt = gaussSeidel!(Qlist, Vshort,1.2,1)# at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:268
#ProfileView.view()

# %%
# for cidx in 1:g_nScomp
#     S = CIDX2S(cidx) 
#     a = ctmdpPolicy(S)
#     if a != g_noaction
#         @printf("%s -> %s\n",S, a) 
#     end
# end
