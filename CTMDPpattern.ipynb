# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
β_cost = 0.0;
legalActions = validCompactActions
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
P0 = spzeros(g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])
        end
    end
end
M0 = speye(g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./(teaTime[s]/60)
end

Isp = spdiagm(ones(g_nNodes));
Qt_list = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
 #g_nScomp 
Vshort = zeros(Float32,g_nSlong);

# %%
g_nScomp, g_nSlong / g_nScomp,
# Out:
# (27405,19.392118226600985)

# %%
using ProfileView
using CPUTime
Profile.init(1000000*10, 0.001)

# %%
Profile.clear()
@profile Aopt = gaussSeidel!(Qt_list, Vshort, 0.1; maxTime = 20.); #at ... 
unique(Aopt)
#Aopt = gaussSeidel!(Qt_list, Vshort, 0.1; maxTime = 20.);
# Out:
# At iteration #5
#  (2.46 sec)
# At iteration #
# 10 (5.06 sec)
# At iteration #
# 15 (7.52 sec)
# At iteration #
# 20 (10.00 sec)
# At iteration #
# 25 (12.46 sec)
# At iteration #
# 30 (14.97 sec)
# At iteration #
# 35 (17.45 sec)
# At iteration #
# 40 (19.94 sec)
# Stopping after 41 iterations (maxVchange = 1.50)
# elapsed time: 20.000079066 seconds (9377068652 bytes allocated, 31.38% gc time)
# Aopt not defined
# while loading In[7], in expression starting on line 3

# %%
ProfileView.view()
# Out:
# ProfileData(5899x18 Array{RGB{Float64},2}:
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0),[0x00007fb4b2276b20=>LineInfo("getindex","sparse/sparsematrix.jl",803,false,140414059768608),0x00007fb4b2275456=>LineInfo("getindex","sparse/sparsematrix.jl",762,false,140414059762774),0x00007fb4b2276192=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",137,false,140414059766162),0x00007fb4ba6e6607=>LineInfo("setindex!","sparse/sparsematrix.jl",1237,false,140414198638087),0x00007fb4b227566b=>LineInfo("Qti_ABt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",173,false,140414059763307),0x00007fb4bac74362=>LineInfo("typeinf","./inference.jl",1409,false,140414204461922),0x00007fb4b2276f09=>LineInfo("getindex","sparse/sparsematrix.jl",806,false,140414059769609),0x00007fb4bd1195a7=>LineInfo("???","???",140414242887079,true,140414242887079),0x00007fb4ba6e6da3=>LineInfo("_deleteat!","array.jl",426,false,140414198640035),0x00007fb4ba6aa849=>LineInfo("eventloop","/home/zouhair/.julia/v0.3/IJulia/src/IJulia.jl",123,false,140414198392905),0x00007fb4be1910d0=>LineInfo("???","???",140414260154576,true,140414260154576),0x00007fb4bd1279e6=>LineInfo("jl_gc_collect","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242945510),0x00007fb4b2275f01=>LineInfo("eaKronv!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",87,false,140414059765505),0x00007fb4b22751a4=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",242,false,140414059762084),0x00007fb4b22779ad=>LineInfo("_mapreduce","reduce.jl",169,false,140414059772333),0x00007fb4ba6e722e=>LineInfo("insert!","array.jl",548,false,140414198641198),0x00007fb4bac693e1=>LineInfo("abstract_call","./inference.jl",819,false,140414204416993),0x00007fb4bd128019=>LineInfo("???","???",140414242947097,true,140414242947097),0x00007fb4bd128271=>LineInfo("allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242947697),0x00007fb4bd11402b=>LineInfo("jl_box_int64","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242865195),0x00007fb4b2275b53=>LineInfo("+","sparse/sparsematrix.jl",594,false,140414059764563),0x00007fb4ba6e079b=>LineInfo("ht_keyindex","dict.jl",481,false,140414198613915),0x00007fb4ba6e47f4=>LineInfo("spzeros","sparse/sparsematrix.jl",405,false,140414198630388),0x00007fb4ba6e744d=>LineInfo("searchsortedfirst","sort.jl",132,false,140414198641741),0x00007fb4ba6e034f=>LineInfo("sort","sort.jl",358,false,140414198612815),0x00007fb4bd0bdae4=>LineInfo("jl_is_leaf_type","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242511588),0x00007fb4b2274eb1=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",214,false,140414059761329),0x00007fb4ba6e66e4=>LineInfo("setindex!","sparse/sparsematrix.jl",1256,false,140414198638308),0x00007fb4bd119efa=>LineInfo("jl_alloc_array_1d","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242889466),0x00007fb4bd112db3=>LineInfo("jl_alloc_tuple","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242860467),0x00007fb4b22761f8=>LineInfo("Cbt","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",144,false,140414059766264),0x00007fb4bd119dc2=>LineInfo("jl_alloc_array_1d","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242889154),0x00007fb4b2275440=>LineInfo("getindex","sparse/sparsematrix.jl",761,false,140414059762752),0x00007fb4ba6e7080=>LineInfo("_growat_end!","array.jl",412,false,140414198640768),0x00007fb4bd0cdfcb=>LineInfo("jl_apply_generic","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242578379),0x00007fb4be1947c0=>LineInfo("???","???",140414260168640,true,140414260168640),0x00007fb4bd119ee5=>LineInfo("jl_alloc_array_1d","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140414242889445),0x00007fb4b2274e45=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",208,false,140414059761221),0x00007fb4bac77274=>LineInfo("jlcall_typeinf_4857","/usr/bin/../lib/x86 ...
#  TagData(0x00007fb4ba6ad24f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x00007fb4bac71bdd,1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x00007fb4bac71bdd,1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x00007fb4bac71bdd,1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x00007fb4bac71bdd,1)
#  TagData(0x00007fb4ba6ad24f,0)  …  TagData(0x00007fb4bac71bdd,1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  ⋮                              ⋱
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)  …  TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1)
#  TagData(0x00007fb4ba6ad24f,0)     TagData(0x0000000000000000,-1),12)

# %%
ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# filename = "CTMDPpolicy_a_" * string(α) * "_b_" * string(β_cost) * ".jld"
# save(filename, "Aopt", Aopt, "Vstar", Vshort, "α", α, "β_cost", β_cost);
# filename

# %%
s = [:LD2,:RD2, :T, :T]; s2 = [:LB1,:LD1, :T, :T];#,:T,:T]#,:LArr];

# %%
ctmdpPolicy(s), ctmdpPolicy(s2)
# Out:
# ((2,:RD3),(0,:∅))

# %%
P[3][s2x(s[1]),:]
# Out:
# 1x27 sparse matrix with 1 Float64 entries:
# 	[1 , 22]  =  1.0

# %%
q1 = Qi(Qlist[1], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q3 = Qi(Qlist[3], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q1, q3
# Out:
# (
# 531441x1 sparse matrix with 7 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[220159,      1]  =  0.25
# 	[416989,      1]  =  0.25,
#
# 531441x1 sparse matrix with 6 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[416989,      1]  =  0.5)

# %%
[(LIDX2S(lidx),q1[lidx]) for lidx in q1.rowval[q1.colptr[1]:(q1.colptr[2]-1)]]
# Out:
# 7-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RB1,:LD2,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.24999999500000009)

# %%
[(LIDX2S(lidx),q3[lidx]) for lidx in q3.rowval[q3.colptr[1]:(q3.colptr[2]-1)]]
# Out:
# 6-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.49999999000000017)

# %%
s = [:RD2,:LD2]
for ac in legalActions(s)
    a = compAct2extAct(ac,s)
    X =  sort(S2X(s))
    @printf("a = %s (%s), Q(V,a)=%.2f \n",a, ac, QVeval(X,ac, Qlist,Vshort,1e6))
    for sp in getNextPerms(s)
        tp = Transition(s, a, sp)
        for spp in getNextPerms(sp)
            @printf("%s->%s->%s, p = %.2f, R = %.2f, V=%.2f\n",
            s, sp, spp,
            tp * Transition(sp, g_noaction, spp), Reward(spp, g_nullAct,0.1),
            Vshort[S2CIDX(spp)]
            )
        end
    end
end
# Out:
# key not found: [6,11]
# while loading In[21], in expression starting on line 2
#
#  in X2CIDX at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:75
#  in QVeval at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:232
#  in anonymous at no file:5

# %%
legalActions(s)
# Out:
# 5x1 Array{Array{Int64,1},2}:
#  [0,0]
#  [1,1]
#  [1,2]
#  [2,1]
#  [2,2]

# %%
#popo = [CIDX2S(cidx) => policy_S2a(CIDX2S(cidx),Aopt) for cidx in find(x-> x != g_noaction, Aopt)]

# %%
#using ProfileView
#@profile Aopt = gaussSeidel!(Qlist, Vshort,1.2,1)# at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:268
#ProfileView.view()

# %%
# for cidx in 1:g_nScomp
#     S = CIDX2S(cidx) 
#     a = ctmdpPolicy(S)
#     if a != g_noaction
#         @printf("%s -> %s\n",S, a) 
#     end
# end
