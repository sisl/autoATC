# %%
include("pattern.jl")
# Out:
# plotSim (generic function with 1 method)

# %%
include("CTMDP.jl")
# Out:
# sample (generic function with 1 method)

# %%
β_cost = 0.0;
legalActions = validCompactActions
amax = maximum([length( NextStates[s]) for s in keys(NextStates)]);
A = (Int64)[0:amax];
P0 = spzeros(g_nNodes, g_nNodes);
P = (typeof(P0))[copy(P0) for a in A]

for a in A
    if a == 0
        act = g_nullAct
    else
        act = Int64[1, a]
    end
    for x in 1:g_nNodes
        s = x2s(x)
        for sp in NextStates[s]
            xp = s2x(sp)
            P[a+1][x,xp] = Transition([s], act, [sp])
        end
    end
end
M0 = speye(g_nNodes)
for x in 1:g_nNodes
    s = x2s(x)
    M0[x,x] = 1./(teaTime[s]/60)
end

Isp = spdiagm(ones(g_nNodes));
Qt_list = (typeof(M0))[(M0*(P[a+1] - Isp))' for a in A];

# %%
 #g_nScomp 
Vshort = zeros(Float32,g_nSlong);

# %%
g_nScomp, g_nSlong / g_nScomp,
# Out:
# (3321960,22.518393057110863)

# %%
g_nSlong
# Out:
# 74805201

# %%
using CPUTime

using ProfileView
Profile.init(1000000*10, 0.001)

# %%
Aopt = @profile gaussSeidel!(Qt_list, Vshort, 0.1; maxIters = 1, maxTime = 20.);
unique(Aopt)
#1 phase takes  .5s / iteration 
#2 phase takes   3s / iteration
#3 phase takes  ~12s / iteration 
#4 phase takes ~17s / iteration
# Out:
# Stopping after 1
#  iterations (maxVchange = 19932.54)
# elapsed time: 17
# .701882482 seconds (756803516 bytes allocated, 16.64% gc time)
# 7-element Array{Array{Int64,1},1}:
#  [0,0]
#  [4,2]
#  [3,1]
#  [3,2]
#  [2,1]
#  [2,2]
#  [1,2]

# %%
ProfileView.view()
# Out:
# ProfileData(2826x57 Array{RGB{Float64},2}:
#  RGB{Float64}(0.0,0.0,0.0)                                                …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)     RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.47034102652604887,0.3548485806834522,0.9887746568367514)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                   RGB{Float64}(0.0,0.0,0.0)
#  ⋮                                                                        ⋱
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                 …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.032953713619640335,0.546608346245583,0.0)                    RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                                                …  RGB{Float64}(0.0,0.0,0.0),[0x00007f8a2f7592a3=>LineInfo("???","???",140231478448803,true,140231478448803),0x00007f8a2eea62a0=>LineInfo("???","???",140231469327008,true,140231469327008),0x00007f8a2efbfa51=>LineInfo("???","???",140231470479953,true,140231470479953),0x00007f8a2f3d6c5f=>LineInfo("???","???",140231474768991,true,140231474768991),0x00007f8a2ca32189=>LineInfo("is_known_call_p","./inference.jl",2796,false,140231431102857),0x00007f8a2ca48a21=>LineInfo("inlining_pass","./inference.jl",2667,false,140231431195169),0x00007f8a2eeb38d9=>LineInfo("???","???",140231469381849,true,140231469381849),0x00007f8a2ca40867=>LineInfo("inlineable","./inference.jl",2025,false,140231431161959),0x00007f8a2ef11508=>LineInfo("alloc_2w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140231469765896),0x00007f8a24051861=>LineInfo("QVeval","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",234,false,140231286528097),0x00007f8a2f07ec4e=>LineInfo("???","???",140231471262798,true,140231471262798),0x00007f8a24052cdc=>LineInfo("Ppq_v!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",51,false,140231286533340),0x00007f8a2f44a501=>LineInfo("???","???",140231475242241,true,140231475242241),0x00007f8a2eeac93d=>LineInfo("???","???",140231469353277,true,140231469353277),0x00007f8a2ca1d26d=>LineInfo("replace_tupleref!","./inference.jl",3034,false,140231431017069),0x00007f8a2eea5087=>LineInfo("???","???",140231469322375,true,140231469322375),0x00007f8a2ef11407=>LineInfo("allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140231469765639),0x00007f8a2f025285=>LineInfo("???","???",140231470895749,true,140231470895749),0x00007f8a2f31eb3e=>LineInfo("???","???",140231474015038,true,140231474015038),0x00007f8a2f0875f5=>LineInfo("???","???",140231471298037,true,140231471298037),0x00007f8a2f04ba9c=>LineInfo("???","???",140231471053468,true,140231471053468),0x00007f8a2e88c5c0=>LineInfo("memset","/lib/x86_64-linux-gnu/libc.so.6",-1,true,140231462929856),0x00007f8a2ef3425a=>LineInfo("???","???",140231469908570,true,140231469908570),0x00007f8a2ef03f1b=>LineInfo("jl_array_grow_end","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140231469711131),0x00007f8a2eeeb9eb=>LineInfo("???","???",140231469611499,true,140231469611499),0x00007f8a2ef25a65=>LineInfo("???","???",140231469849189,true,140231469849189),0x00007f8a2ca33d24=>LineInfo("resolve_globals","./inference.jl",1801,false,140231431109924),0x00007f8a2eeb3844=>LineInfo("???","???",140231469381700,true,140231469381700),0x00007f8a240526f5=>LineInfo("Cbt!","/home/zouhair/Dropbox/Research/autoATC/kronfun.jl",169,false,140231286531829),0x00007f8a2eeae0a0=>LineInfo("???","???",140231469359264,true,140231469359264),0x00007f8a2eea8bae=>LineInfo("???","???",140231469337518,true,140231469337518),0x00007f8a2eebd94c=>LineInfo("jl_f_isdefined","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140231469422924),0x00007f8a2ef0fb1f=>LineInfo("???","???",140231469759263,true,140231469759263),0x00007f8a2ca513cb=>LineInfo("abstract_call_gf","./inference.jl",685,false,140231431230411),0x00007f8a240514d8=>LineInfo("X2LIDX","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",107,false,140231286527192),0x00007f8a2c9e3256=>LineInfo("anonymous","./no file",626,false,140231430779478),0x00007f8a2ca313ec=>LineInfo("unique_name","./inference.jl",2755,false,140231431099372),0x00007f8a240544e4=>LineInfo("NcolNtaxi","/home/zouhair/Dropbox/Research/autoATC/CTMDP.jl",273,false,140231286539492),0x00007f8a2c49af46=>LineInfo("execute_request_0x535c5df2","/home/zouhair/.julia/v0.3/IJulia/src/execute_request.jl",160,false,140231425240902),0x00007f8a2eebf5b8=>LineInfo("jl_object_id","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,true,140231469430200),0x00007f8a2f09029d=>LineInfo("???","???",140231471334045,true,140231471334045),0x00007f8a2f0e1e53=>LineInfo("???","???",140231471668819,true,140231471668819),0x00007f8a2f3a5 ...
#  TagData(0x0000000000000000,-1)  …  TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c48b04e,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c48b04e,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)  …  TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)     TagData(0x0000000000000000,-1)
#  ⋮                               ⋱
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)   …  TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x00007f8a2c4922b6,0)      TagData(0x0000000000000000,-1)
#  TagData(0x0000000000000000,-1)  …  TagData(0x0000000000000000,-1),12)

# %%
ctmdpPolicy = S -> policy_S2a(S, Aopt)
# Out:
# (anonymous function)

# %%
# filename = "CTMDPpolicy_a_" * string(α) * "_b_" * string(β_cost) * ".jld"
# save(filename, "Aopt", Aopt, "Vstar", Vshort, "α", α, "β_cost", β_cost);
# filename

# %%
s = [:LD2,:RD2, :T, :T]; s2 = [:F1,:U1, :LX1, :T];#,:T,:T]#,:LArr];

# %%
ctmdpPolicy(s), ctmdpPolicy(s2)
# Out:
# ((1,:ϕ1_LB1),(1,:ϕ1_GO))

# %%
P[3][s2x(s[1]),:]
# Out:
# 1x27 sparse matrix with 1 Float64 entries:
# 	[1 , 22]  =  1.0

# %%
q1 = Qi(Qlist[1], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q3 = Qi(Qlist[3], Qlist[1], g_nVehicles-1, S2LIDX(s))/0.360848
q1, q3
# Out:
# (
# 531441x1 sparse matrix with 7 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[220159,      1]  =  0.25
# 	[416989,      1]  =  0.25,
#
# 531441x1 sparse matrix with 6 Float64 entries:
# 	[200476,      1]  =  -2.44424
# 	[200477,      1]  =  0.722118
# 	[200503,      1]  =  0.722118
# 	[201205,      1]  =  0.25
# 	[208495,      1]  =  0.25
# 	[416989,      1]  =  0.5)

# %%
[(LIDX2S(lidx),q1[lidx]) for lidx in q1.rowval[q1.colptr[1]:(q1.colptr[2]-1)]]
# Out:
# 7-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RB1,:LD2,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.24999999500000009)

# %%
[(LIDX2S(lidx),q3[lidx]) for lidx in q3.rowval[q3.colptr[1]:(q3.colptr[2]-1)]]
# Out:
# 6-element Array{(Array{Symbol,1},Any),1}:
#  ([:RD2,:LD2,:T,:T],-2.4442369006505698)
#  ([:RD2,:LD2,:T,:R],0.7221184603252847)
#  ([:RD2,:LD2,:R,:T],0.7221184603252847)
#  ([:RD2,:LB1,:T,:T],0.24999999500000009)
#  ([:RD2,:LD3,:T,:T],0.24999999500000009)
#  ([:RD3,:LD2,:T,:T],0.49999999000000017)

# %%
s = [:RD2,:LD2]
for ac in legalActions(s)
    a = compAct2extAct(ac,s)
    X =  sort(S2X(s))
    @printf("a = %s (%s), Q(V,a)=%.2f \n",a, ac, QVeval(X,ac, Qlist,Vshort,1e6))
    for sp in getNextPerms(s)
        tp = Transition(s, a, sp)
        for spp in getNextPerms(sp)
            @printf("%s->%s->%s, p = %.2f, R = %.2f, V=%.2f\n",
            s, sp, spp,
            tp * Transition(sp, g_noaction, spp), Reward(spp, g_nullAct,0.1),
            Vshort[S2CIDX(spp)]
            )
        end
    end
end
# Out:
# key not found: [6,11]
# while loading In[21], in expression starting on line 2
#
#  in X2CIDX at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:75
#  in QVeval at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:232
#  in anonymous at no file:5

# %%
legalActions(s)
# Out:
# 5x1 Array{Array{Int64,1},2}:
#  [0,0]
#  [1,1]
#  [1,2]
#  [2,1]
#  [2,2]

# %%
#popo = [CIDX2S(cidx) => policy_S2a(CIDX2S(cidx),Aopt) for cidx in find(x-> x != g_noaction, Aopt)]

# %%
#using ProfileView
#@profile Aopt = gaussSeidel!(Qlist, Vshort,1.2,1)# at /home/zouhair/Dropbox/Research/autoATC/CTMDP.jl:268
#ProfileView.view()

# %%
# for cidx in 1:g_nScomp
#     S = CIDX2S(cidx) 
#     a = ctmdpPolicy(S)
#     if a != g_noaction
#         @printf("%s -> %s\n",S, a) 
#     end
# end
